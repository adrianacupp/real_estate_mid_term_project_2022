# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ### Importing the libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib.colors import ListedColormap

import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import minmax_scale
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PowerTransformer
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import (StandardScaler, MinMaxScaler)
from sklearn.preprocessing import QuantileTransformer

import statsmodels.api as sm
from scipy.stats import boxcox
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import mean_absolute_error as mae
pd.options.display.max_rows = 50
pd.set_option('max_columns', None)

pd.set_option('display.float_format', lambda x: '%0.4f' % x)

# %% [markdown]
# ### Import dataset

# %%
df = pd.read_excel('Data/Data_MidTerm_Project_Real_State_Regression.xls')
df
# Out:
#                id       date  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0      7129300520 2014-10-13         3     1.0000         1180      5650
# 1      6414100192 2014-12-09         3     2.2500         2570      7242
# 2      5631500400 2015-02-25         2     1.0000          770     10000
# 3      2487200875 2014-12-09         4     3.0000         1960      5000
# 4      1954400510 2015-02-18         3     2.0000         1680      8080
# ...           ...        ...       ...        ...          ...       ...
# 21592   263000018 2014-05-21         3     2.5000         1530      1131
# 21593  6600060120 2015-02-23         4     2.5000         2310      5813
# 21594  1523300141 2014-06-23         2     0.7500         1020      1350
# 21595   291310100 2015-01-16         3     2.5000         1600      2388
# 21596  1523300157 2014-10-15         2     0.7500         1020      1076
#
#        floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0      1.0000           0     0          3      7        1180              0
# 1      2.0000           0     0          3      7        2170            400
# 2      1.0000           0     0          3      6         770              0
# 3      1.0000           0     0          5      7        1050            910
# 4      1.0000           0     0          3      8        1680              0
# ...       ...         ...   ...        ...    ...         ...            ...
# 21592  3.0000           0     0          3      8        1530              0
# 21593  2.0000           0     0          3      8        2310              0
# 21594  2.0000           0     0          3      7        1020              0
# 21595  2.0000           0     0          3      8        1600              0
# 21596  2.0000           0     0          3      7        1020              0
#
#        yr_built  yr_renovated  zipcode     lat      long  sqft_living15  \
# 0          1955             0    98178 47.5112 -122.2570           1340
# 1          1951          1991    98125 47.7210 -122.3190           1690
# 2          1933             0    98028 47.7379 -122.2330           2720
# 3          1965             0    98136 47.5208 -122.3930           1360
# 4          1987             0    98074 47.6168 -122.0450           1800
# ...         ...           ...      ...     ...       ...            ...
# 21592      2009             0    98103 47.6993 -122.3460           1530
# 21593      2014             0    98146 47.5107 -122.3620           1830
# 21594      2009             0    98144 47.5944 -122.2990           1020
# 21595      2004             0    98027 47.5345 -122.0690           1410
# 21596      2008             0    98144 47.5941 -122.2990           1020
#
#        sqft_lot15   price
# 0            5650  221900
# 1            7639  538000
# 2            8062  180000
# 3            5000  604000
# 4            7503  510000
# ...           ...     ...
# 21592        1509  360000
# 21593        7200  400000
# 21594        2007  402101
# 21595        1287  400000
# 21596        1357  325000
#
# [21597 rows x 21 columns]

# %%
corr_matrix = df.corr(method='spearman').abs()
corr_matrix
# Out:
#                   id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# id            1.0000    0.0062     0.0151       0.0017    0.1166  0.0189
# bedrooms      0.0062    1.0000     0.5208       0.6477    0.2170  0.2284
# bathrooms     0.0151    0.5208     1.0000       0.7459    0.0692  0.5476
# sqft_living   0.0017    0.6477     0.7459       1.0000    0.3047  0.4012
# sqft_lot      0.1166    0.2170     0.0692       0.3047    1.0000  0.2340
# floors        0.0189    0.2284     0.5476       0.4012    0.2340  1.0000
# waterfront    0.0036    0.0077     0.0495       0.0703    0.0857  0.0239
# view          0.0125    0.0817     0.1560       0.2330    0.1176  0.0192
# condition     0.0239    0.0117     0.1637       0.0631    0.1150  0.2881
# grade         0.0199    0.3804     0.6585       0.7163    0.1525  0.5018
# sqft_above    0.0035    0.5401     0.6914       0.8433    0.2731  0.5992
# sqft_basement 0.0014    0.2298     0.1914       0.3278    0.0368  0.2725
# yr_built      0.0267    0.1806     0.5677       0.3525    0.0373  0.5514
# yr_renovated  0.0175    0.0166     0.0425       0.0526    0.0086  0.0126
# zipcode       0.0053    0.1678     0.2053       0.2072    0.3194  0.0618
# lat           0.0036    0.0218     0.0081       0.0306    0.1219  0.0243
# long          0.0073    0.1925     0.2623       0.2853    0.3705  0.1489
# sqft_living15 0.0002    0.4442     0.5707       0.7470    0.3598  0.3056
# sqft_lot15    0.1146    0.2022     0.0637       0.2846    0.9223  0.2309
# price         0.0043    0.3442     0.4973       0.6440    0.0751  0.3225
#
#                waterfront   view  condition  grade  sqft_above  sqft_basement  \
# id                 0.0036 0.0125     0.0239 0.0199      0.0035         0.0014
# bedrooms           0.0077 0.0817     0.0117 0.3804      0.5401         0.2298
# bathrooms          0.0495 0.1560     0.1637 0.6585      0.6914         0.1914
# sqft_living        0.0703 0.2330     0.0631 0.7163      0.8433         0.3278
# sqft_lot           0.0857 0.1176     0.1150 0.1525      0.2731         0.0368
# floors             0.0239 0.0192     0.2881 0.5018      0.5992         0.2725
# waterfront         1.0000 0.2851     0.0167 0.0622      0.0545         0.0519
# view               0.2851 1.0000     0.0461 0.2171      0.1442         0.2367
# condition          0.0167 0.0461     1.0000 0.1681      0.1586         0.1614
# grade              0.0622 0.2171     0.1681 1.0000      0.7117         0.0927
# sqft_above         0.0545 0.1442     0.1586 0.7117      1.0000         0.1660
# sqft_basement      0.0519 0.2367     0.1614 0.0927      0.1660         1.0000
# yr_built           0.0286 0.0669     0.3939 0.5009      0.4719         0.1779
# yr_renovated       0.0916 0.0966     0.0663 0.0159      0.0309         0.0627
# zipcode            0.0296 0.0780     0.0224 0.1819      0.2790         0.1144
# lat                0.0191 0.0004     0.0225 0.1036      0.0262         0.1161
# long               0.0381 0.1024     0.0850 0.2234      0.3862         0.2000
# sqft_living15      0.0746 0.2560     0.0871 0.6627      0.6967         0.1297
# sqft_lot15         0.0923 0.1171     0.1179 0.1566      0.2550         0.0308
# price              0.1151 0.2939     0.0180 0.6582      0.5416         0.2515
#
#                yr_built  yr_renovated  zipcode    lat   long  sqft_living15  \
# id               0.0267        0.0175   0.0053 0.0036 0.0073         0.0002
# bedrooms         0.1806        0.0166   0.1678 0.0218 0.1925         0.4442
# bathrooms        0.5677        0.0425   0.2053 0.0081 0.2623         0.5707
# sqft_living      0.3525        0.0526   0.2072 0.0306 0.2853         0.7470
# sqft_lot         0.0373        0.0086   0.3194 0.1219 0.3705         0.3598
# floors           0.5514        0.0126   0.0618 0.0243 0.1489         0.3056
# waterfront       0.0286        0.0916   0.0296 0.0191 0.0381         0.0746
# view             0.0669        0.0966   0.0780 0.0004 0.1024         0.2560
# condition        0.3939        0.0663   0.0224 0.0225 0.0850         0.0871
# grade            0.5009        0.0159   0.1819 0.1036 0.2234         0.6627
# sqft_above       0.4719        0.0309   0.2790 0.0262 0.3862         0.6967
# sqft_basement    0.1779        0.0627   0.1144 0.1161 0.2000         0.1297
# yr_built         1.0000        0.2146   0.3173 0.1261 0.4132         0.3362
# yr_renovated     0.2146        1.0000   0.0624 0.0253 0.0751         0.0056
# zipcode          0.3173        0.0624   1.0000 0.2493 0.5772         0.2875
# lat              0.1261        0.0253   0.2493 1.0000 0.1431         0.0275
# long             0.4132        0.0751   0.5772 0.1431 1.0000         0.3811
# sqft_living15    0.3362        0.0056   0.2875 0.0275 0.3811         1.0000
# sqft_lot15       0.0158        0.0089   0.3259 0.1162 0.3730         0.3661
# price            0.1021        0.1018   0.0091 0.4561 0.0641         0.5723
#
#                sqft_lot15  price
# id                 0.1146 0.0043
# bedrooms           0.2022 0.3442
# bathrooms          0.0637 0.4973
# sqft_living        0.2846 0.6440
# sqft_lot           0.9223 0.0751
# floors             0.2309 0.3225
# waterfront         0.0923 0.1151
# view               0.1171 0.2939
# condition          0.1179 0.0180
# grade              0.1566 0.6582
# sqft_above         0.2550 0.5416
# sqft_basement      0.0308 0.2515
# yr_built           0.0158 0.1021
# yr_renovated       0.0089 0.1018
# zipcode            0.3259 0.0091
# lat                0.1162 0.4561
# long               0.3730 0.0641
# sqft_living15      0.3661 0.5723
# sqft_lot15         1.0000 0.0631
# price              0.0631 1.0000

# %%
np.percentile

# %%
df.price = np.log(df.price.values)

# %%
df.price.hist()
# Out:
# <AxesSubplot:>

# %%
sns.histplot(np.log(df.price.values))
# Out:
# <AxesSubplot:ylabel='Count'>

# %% [markdown]
# ### Columns type

# %% [markdown]
# ### Drop not relevant columns

# %%
df = df.drop(['id','lat', 'long', 'date', 'bedrooms', 'sqft_lot', 'floors', 'condition', 'sqft_above', 'sqft_basement', 'yr_renovated', 'sqft_living15', 'sqft_lot15'], axis=1)
df
# Out:
#        bathrooms  sqft_living  waterfront  view  grade  yr_built  zipcode  \
# 0         1.0000         1180           0     0      7      1955    98178
# 1         2.2500         2570           0     0      7      1951    98125
# 2         1.0000          770           0     0      6      1933    98028
# 3         3.0000         1960           0     0      7      1965    98136
# 4         2.0000         1680           0     0      8      1987    98074
# ...          ...          ...         ...   ...    ...       ...      ...
# 21592     2.5000         1530           0     0      8      2009    98103
# 21593     2.5000         2310           0     0      8      2014    98146
# 21594     0.7500         1020           0     0      7      2009    98144
# 21595     2.5000         1600           0     0      8      2004    98027
# 21596     0.7500         1020           0     0      7      2008    98144
#
#         price
# 0     12.3100
# 1     13.1956
# 2     12.1007
# 3     13.3113
# 4     13.1422
# ...       ...
# 21592 12.7939
# 21593 12.8992
# 21594 12.9045
# 21595 12.8992
# 21596 12.6916
#
# [21597 rows x 8 columns]

# %% [markdown]
# ### Checking Columns

# %%
df = df.drop(15856).reset_index(drop=True)

# %%
df
# Out:
#        bathrooms  sqft_living  waterfront  view  grade  yr_built  zipcode  \
# 0         1.0000         1180           0     0      7      1955    98178
# 1         2.2500         2570           0     0      7      1951    98125
# 2         1.0000          770           0     0      6      1933    98028
# 3         3.0000         1960           0     0      7      1965    98136
# 4         2.0000         1680           0     0      8      1987    98074
# ...          ...          ...         ...   ...    ...       ...      ...
# 21591     2.5000         1530           0     0      8      2009    98103
# 21592     2.5000         2310           0     0      8      2014    98146
# 21593     0.7500         1020           0     0      7      2009    98144
# 21594     2.5000         1600           0     0      8      2004    98027
# 21595     0.7500         1020           0     0      7      2008    98144
#
#         price
# 0     12.3100
# 1     13.1956
# 2     12.1007
# 3     13.3113
# 4     13.1422
# ...       ...
# 21591 12.7939
# 21592 12.8992
# 21593 12.9045
# 21594 12.8992
# 21595 12.6916
#
# [21596 rows x 8 columns]

# %%
df['bathrooms'].value_counts()
# Out:
# 2.5000    5377
# 1.0000    3851
# 1.7500    3047
# 2.2500    2047
# 2.0000    1930
# 1.5000    1445
# 2.7500    1185
# 3.0000     753
# 3.5000     731
# 3.2500     589
# 3.7500     155
# 4.0000     136
# 4.5000     100
# 4.2500      79
# 0.7500      71
# 4.7500      23
# 5.0000      21
# 5.2500      13
# 5.5000      10
# 1.2500       9
# 6.0000       6
# 0.5000       4
# 5.7500       4
# 6.7500       2
# 8.0000       2
# 6.2500       2
# 6.5000       2
# 7.5000       1
# 7.7500       1
# Name: bathrooms, dtype: int64

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Transform yr_built and yr_renovated

# %%
df['yr_built']= list(map(lambda x: 2015-x, df['yr_built']))

# %%
df['yr_built']
# Out:
# 0        60
# 1        64
# 2        82
# 3        50
# 4        28
#          ..
# 21591     6
# 21592     1
# 21593     6
# 21594    11
# 21595     7
# Name: yr_built, Length: 21596, dtype: int64

# %%
df.rename(columns = {'yr_built' : 'age_build'}, inplace=True)

# %%
df
# Out:
#        bathrooms  sqft_living  waterfront  view  grade  age_build  zipcode  \
# 0         1.0000         1180           0     0      7         60    98178
# 1         2.2500         2570           0     0      7         64    98125
# 2         1.0000          770           0     0      6         82    98028
# 3         3.0000         1960           0     0      7         50    98136
# 4         2.0000         1680           0     0      8         28    98074
# ...          ...          ...         ...   ...    ...        ...      ...
# 21591     2.5000         1530           0     0      8          6    98103
# 21592     2.5000         2310           0     0      8          1    98146
# 21593     0.7500         1020           0     0      7          6    98144
# 21594     2.5000         1600           0     0      8         11    98027
# 21595     0.7500         1020           0     0      7          7    98144
#
#         price
# 0     12.3100
# 1     13.1956
# 2     12.1007
# 3     13.3113
# 4     13.1422
# ...       ...
# 21591 12.7939
# 21592 12.8992
# 21593 12.9045
# 21594 12.8992
# 21595 12.6916
#
# [21596 rows x 8 columns]

# %%
## df['bathrooms'] = df['bathrooms'].replace([11,10],9)
## df['bathrooms'].unique()

# %%
## sns.barplot(x = categorical['bedrooms'],y = df['price'])

# %% [markdown]
# ### Normalize numerical

# %%
df.hist(figsize=(15,15), xrot=-45)
plt.show()

# %%
# qt = QuantileTransformer(output_distribution = 'normal')
#df['sqft_living'] = qt.fit_transform(df['sqft_living'].to_numpy().reshape(-1,1))
#sns.displot(df['sqft_living'])

# %% [markdown]
# ### Transform zipcode

# %%
price_zip_mean = df.groupby(['zipcode'])['price'].mean()
price_zip_mean.sort_values(ascending=False)
# Out:
# zipcode
# 98039   14.4704
# 98004   14.0087
# 98040   13.9030
# 98112   13.7798
# 98109   13.5857
#           ...
# 98023   12.5124
# 98001   12.4931
# 98032   12.3982
# 98168   12.3445
# 98002   12.3377
# Name: price, Length: 70, dtype: float64

# %%
price_zip = df.groupby(['zipcode'])['price'].mean()
pz = price_zip.sort_values(ascending=False).reset_index()
pz
# Out:
#     zipcode   price
# 0     98039 14.4704
# 1     98004 14.0087
# 2     98040 13.9030
# 3     98112 13.7798
# 4     98109 13.5857
# ..      ...     ...
# 65    98023 12.5124
# 66    98001 12.4931
# 67    98032 12.3982
# 68    98168 12.3445
# 69    98002 12.3377
#
# [70 rows x 2 columns]

# %%
df
# Out:
#        bathrooms  sqft_living  waterfront  view  grade  age_build  zipcode  \
# 0         1.0000         1180           0     0      7         60    98178
# 1         2.2500         2570           0     0      7         64    98125
# 2         1.0000          770           0     0      6         82    98028
# 3         3.0000         1960           0     0      7         50    98136
# 4         2.0000         1680           0     0      8         28    98074
# ...          ...          ...         ...   ...    ...        ...      ...
# 21591     2.5000         1530           0     0      8          6    98103
# 21592     2.5000         2310           0     0      8          1    98146
# 21593     0.7500         1020           0     0      7          6    98144
# 21594     2.5000         1600           0     0      8         11    98027
# 21595     0.7500         1020           0     0      7          7    98144
#
#         price
# 0     12.3100
# 1     13.1956
# 2     12.1007
# 3     13.3113
# 4     13.1422
# ...       ...
# 21591 12.7939
# 21592 12.8992
# 21593 12.9045
# 21594 12.8992
# 21595 12.6916
#
# [21596 rows x 8 columns]

# %%
Q1 = np.percentile(pz['price'], 10)
Q2 = np.percentile(pz['price'], 20)
Q3 = np.percentile(pz['price'], 30)
Q4 = np.percentile(pz['price'], 40)
Q5 = np.percentile(pz['price'], 50)
Q6 = np.percentile(pz['price'], 60)
Q7 = np.percentile(pz['price'], 70)
Q8 = np.percentile(pz['price'], 80)
Q9 = np.percentile(pz['price'], 90)

# %%
pz['quantile_zip'] = "1"
pz['quantile_zip'] = np.where(pz['price'] >= Q1, "2", pz['quantile_zip'])
pz['quantile_zip'] = np.where(pz['price'] >= Q2, "3", pz['quantile_zip'])
pz['quantile_zip'] = np.where(pz['price'] >= Q3, "4", pz['quantile_zip'])
pz['quantile_zip'] = np.where(pz['price'] >= Q4, "5", pz['quantile_zip'])
pz['quantile_zip'] = np.where(pz['price'] >= Q5, "6", pz['quantile_zip'])
pz['quantile_zip'] = np.where(pz['price'] >= Q6, "7", pz['quantile_zip'])
pz['quantile_zip'] = np.where(pz['price'] >= Q7, "8", pz['quantile_zip'])
pz['quantile_zip'] = np.where(pz['price'] >= Q8, "9", pz['quantile_zip'])
pz['quantile_zip'] = np.where(pz['price'] >= Q9, "10", pz['quantile_zip'])

# %%
pz
# Out:
#     zipcode   price quantile_zip
# 0     98039 14.4704           10
# 1     98004 14.0087           10
# 2     98040 13.9030           10
# 3     98112 13.7798           10
# 4     98109 13.5857           10
# ..      ...     ...          ...
# 65    98023 12.5124            1
# 66    98001 12.4931            1
# 67    98032 12.3982            1
# 68    98168 12.3445            1
# 69    98002 12.3377            1
#
# [70 rows x 3 columns]

# %%
pz.groupby('quantile_zip').count()
# Out:
#               zipcode  price
# quantile_zip
# 1                   7      7
# 10                  7      7
# 2                   7      7
# 3                   7      7
# 4                   7      7
# 5                   7      7
# 6                   7      7
# 7                   7      7
# 8                   7      7
# 9                   7      7

# %%
df = pd.merge(df, pz[['zipcode', 'quantile_zip']], on='zipcode', how='inner').sample(frac=1).reset_index(drop=True)

# %%
df
# Out:
#        bathrooms  sqft_living  waterfront  view  grade  age_build  zipcode  \
# 0         1.0000         1120           0     0      7         76    98115
# 1         1.5000         2130           0     0      8         95    98144
# 2         5.0000         4490           0     0     10          2    98004
# 3         2.2500         1820           0     0      7         41    98034
# 4         1.7500         1630           0     0      7         36    98045
# ...          ...          ...         ...   ...    ...        ...      ...
# 21591     2.5000         2310           0     0      8         17    98092
# 21592     1.7500         1140           0     0      7         29    98045
# 21593     2.5000         1900           0     0      7         48    98033
# 21594     2.5000         2030           0     0      7         46    98059
# 21595     1.7500         1400           0     0      7         31    98003
#
#         price quantile_zip
# 0     13.2104            7
# 1     13.5265            6
# 2     14.4033           10
# 3     12.9598            6
# 4     12.6379            5
# ...       ...          ...
# 21591 12.7189            3
# 21592 12.5058            5
# 21593 13.3375            9
# 21594 12.8077            5
# 21595 12.2900            2
#
# [21596 rows x 9 columns]

# %%
df = df.drop(columns=['zipcode', 'bathrooms'], axis=1)

# %%
scaler = MinMaxScaler()
df['sqft_living'] = scaler.fit_transform(df[['sqft_living']])

# %%
df
# Out:
#        sqft_living  waterfront  view  grade  age_build   price quantile_zip
# 0           0.0569           0     0      7         76 13.2104            7
# 1           0.1336           0     0      8         95 13.5265            6
# 2           0.3128           0     0     10          2 14.4033           10
# 3           0.1101           0     0      7         41 12.9598            6
# 4           0.0957           0     0      7         36 12.6379            5
# ...            ...         ...   ...    ...        ...     ...          ...
# 21591       0.1473           0     0      8         17 12.7189            3
# 21592       0.0585           0     0      7         29 12.5058            5
# 21593       0.1162           0     0      7         48 13.3375            9
# 21594       0.1260           0     0      7         46 12.8077            5
# 21595       0.0782           0     0      7         31 12.2900            2
#
# [21596 rows x 7 columns]

# %% [markdown]
# ## Linear Regression (trial 5)

# %% [markdown]
# #### XY Split

# %%
X5=df.drop('price', axis=1)
X5
y5=df.price
y5
# Out:
# 0       13.2104
# 1       13.5265
# 2       14.4033
# 3       12.9598
# 4       12.6379
#           ...
# 21591   12.7189
# 21592   12.5058
# 21593   13.3375
# 21594   12.8077
# 21595   12.2900
# Name: price, Length: 21596, dtype: float64

# %%
X5
# Out:
#        sqft_living  waterfront  view  grade  age_build quantile_zip
# 0           0.0569           0     0      7         76            7
# 1           0.1336           0     0      8         95            6
# 2           0.3128           0     0     10          2           10
# 3           0.1101           0     0      7         41            6
# 4           0.0957           0     0      7         36            5
# ...            ...         ...   ...    ...        ...          ...
# 21591       0.1473           0     0      8         17            3
# 21592       0.0585           0     0      7         29            5
# 21593       0.1162           0     0      7         48            9
# 21594       0.1260           0     0      7         46            5
# 21595       0.0782           0     0      7         31            2
#
# [21596 rows x 6 columns]

# %% [markdown]
# #### Data Splitting

# %%
X_train5, X_test5, y_train5, y_test5 = train_test_split(X5, y5, test_size=.30,random_state=123)

# %% [markdown]
# #### Standardize

# %%
std_scaler5 = StandardScaler().fit(X_train5) 

X_train_scaled5 = std_scaler5.transform(X_train5)

# %%
X_test_scaled5 = std_scaler5.transform(X_test5)

# %%
print(X_train_scaled5)
print("--------")
print(X_test_scaled5)
# Out:
# [[ 0.48559025 -0.07910166 -0.30003031  0.29951457  2.14629374  0.92258972]
#  [ 0.2351369  -0.07910166 -0.30003031  0.29951457 -0.34168994  0.92258972]
#  [-1.28936172 -0.07910166 -0.30003031 -1.40939721  1.77139209  0.55655149]
#  ...
#  [-0.0806521  -0.07910166 -0.30003031 -0.55494132  0.10137565  0.19051325]
#  [-0.25488051 -0.07910166 -0.30003031 -0.55494132 -1.39823095 -0.54156322]
#  [-0.89734779 -0.07910166 -0.30003031 -0.55494132 -0.78475552 -0.54156322]]
# --------
# [[-0.63600517 -0.07910166 -0.30003031  0.29951457  0.44219533  1.28862796]
#  [-0.23310196 -0.07910166 -0.30003031  1.15397046 -1.33006701  0.92258972]
#  [ 0.13713342 -0.07910166 -0.30003031  0.29951457 -0.58026371  1.28862796]
#  ...
#  [-0.00442717 -0.07910166 -0.30003031 -0.55494132 -0.95516536 -0.90760145]
#  [ 1.83586046 -0.07910166 -0.30003031  1.15397046  0.71485108  1.28862796]
#  [-0.668673   -0.07910166 -0.30003031 -1.40939721  1.94180193  0.55655149]]

# %%
X_train_const_scaled5 = sm.add_constant(X_train_scaled5) 

model5 = sm.OLS(y_train5, X_train_const_scaled5).fit()
predictions_train5 = model5.predict(X_train_const_scaled5) 

X_test_const_scaled5 = sm.add_constant(X_test_scaled5) 
predictions_test5 = model5.predict(X_test_const_scaled5) 
print_model5 = model5.summary()
print(print_model5)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.831
# Model:                            OLS   Adj. R-squared:                  0.831
# Method:                 Least Squares   F-statistic:                 1.236e+04
# Date:                Wed, 09 Feb 2022   Prob (F-statistic):               0.00
# Time:                        16:55:01   Log-Likelihood:                 1707.3
# No. Observations:               15117   AIC:                            -3401.
# Df Residuals:                   15110   BIC:                            -3347.
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         13.0410      0.002   7416.995      0.000      13.038      13.044
# x1             0.1891      0.003     68.899      0.000       0.184       0.194
# x2             0.0346      0.002     18.216      0.000       0.031       0.038
# x3             0.0491      0.002     24.435      0.000       0.045       0.053
# x4             0.1451      0.003     46.945      0.000       0.139       0.151
# x5             0.0658      0.002     31.613      0.000       0.062       0.070
# x6             0.2621      0.002    133.773      0.000       0.258       0.266
# ==============================================================================
# Omnibus:                      779.211   Durbin-Watson:                   1.979
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2081.905
# Skew:                          -0.275   Prob(JB):                         0.00
# Kurtosis:                       4.733   Cond. No.                         3.34
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# #### Model validation

# %%
#using sklearn
model5=LinearRegression()    # model
model5.fit(X_train_scaled5, y_train5)   # model train
# Out:
# LinearRegression()

# %%
model5.coef_ #gives you per column the slope (alpha)
# Out:
# array([0.18911896, 0.0346073 , 0.04907371, 0.14505071, 0.06577216,
#        0.26211618])

# %%
model5.intercept_ #gives the optimal slope
# Out:
# 13.04099311956344

# %%
R2_test5 = model5.score(X_test_scaled5,y_test5) # measure R2
R2_test5
# Out:
# 0.8297471836630574

# %%
# Making prediction
y_pred5 = model5.predict(X_test_scaled5)
y_pred5
# Out:
# array([13.31355056, 13.30117656, 13.39251638, ..., 12.64147982,
#        13.9228998 , 12.96623688])

# %%
y_test5
# Out:
# 14863   13.4381
# 2277    13.5008
# 21578   13.3130
# 18669   13.0002
# 21453   12.4169
#           ...
# 12811   14.1448
# 12288   13.2794
# 6556    12.7293
# 16310   14.2729
# 1050    12.9360
# Name: price, Length: 6479, dtype: float64

# %%
result=pd.DataFrame({"y_test":y_test5,"y_pred":y_pred5})

# %%
# Make an scatter plot y_pred vs y
# What kind of plot you will get if all the all the predictions are ok?
# A stright line

fig, ax = plt.subplots(1,3,figsize=(14,4))
ax[0].plot(y_pred5, y_test5, 'o')
ax[0].set_xlabel("y_test")
ax[0].set_ylabel("y_pred")
ax[0].set_title("Test Set -Predicted vs real")

# Get a histogram of the residuals ie: y - y_pred.  Homoscdasticity
# It resembles a normal distribution?
ax[1].hist(y_test5 - y_pred5)
ax[1].set_xlabel("Test y-y_pred")
ax[1].set_title("Test Set Residual histogram")

ax[2].plot(y_pred5,y_test5 - y_pred5,"o")
ax[2].set_xlabel("predited")
ax[2].set_ylabel("residuals")
ax[2].set_title("Residuals by Predicted")
ax[2].plot(y_pred5,np.zeros(len(y_pred5)),linestyle='dashed')

# %%
sns.regplot(x='y_pred',y='y_test', data=result, scatter_kws={"color": "red"}, line_kws={"color": "black"})
# Out:
# <AxesSubplot:xlabel='y_pred', ylabel='y_test'>

# %% [markdown]
# #### Error metrics

# %%
print(mse(y_test5,y_pred5))
print(mae(y_test5,y_pred5))
# Out:
# 0.047655956006573304
# 0.16499863549554566

# %% [markdown]
# #### Features Importance

# %%
features_importances5 = pd.DataFrame(data={
    'Attribute': X_train5.columns,
    'Importance': abs(model5.coef_)
})
features_importances5 = features_importances5.sort_values(by='Importance', ascending=False)
features_importances5
# Out:
#       Attribute  Importance
# 5  quantile_zip      0.2621
# 0   sqft_living      0.1891
# 3         grade      0.1451
# 4     age_build      0.0658
# 2          view      0.0491
# 1    waterfront      0.0346
