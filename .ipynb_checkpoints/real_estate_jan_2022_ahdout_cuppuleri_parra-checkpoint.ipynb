# %% [markdown]
# Goal of the study: Identify the variables with the highest impact on the final house price

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ### Importing the libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib.colors import ListedColormap

import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import minmax_scale
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PowerTransformer
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import (StandardScaler, MinMaxScaler)
from sklearn.preprocessing import QuantileTransformer

import statsmodels.api as sm
from scipy.stats import boxcox
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import mean_absolute_error as mae
pd.options.display.max_rows = 50
pd.set_option('max_columns', None)

pd.set_option('display.float_format', lambda x: '%0.4f' % x)

# %% [markdown]
# ### Import dataset

# %%
df = pd.read_excel('Data/Data_MidTerm_Project_Real_State_Regression.xls')
df
# Out:
#                id       date  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0      7129300520 2014-10-13         3     1.0000         1180      5650
# 1      6414100192 2014-12-09         3     2.2500         2570      7242
# 2      5631500400 2015-02-25         2     1.0000          770     10000
# 3      2487200875 2014-12-09         4     3.0000         1960      5000
# 4      1954400510 2015-02-18         3     2.0000         1680      8080
# ...           ...        ...       ...        ...          ...       ...
# 21592   263000018 2014-05-21         3     2.5000         1530      1131
# 21593  6600060120 2015-02-23         4     2.5000         2310      5813
# 21594  1523300141 2014-06-23         2     0.7500         1020      1350
# 21595   291310100 2015-01-16         3     2.5000         1600      2388
# 21596  1523300157 2014-10-15         2     0.7500         1020      1076
#
#        floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0      1.0000           0     0          3      7        1180              0
# 1      2.0000           0     0          3      7        2170            400
# 2      1.0000           0     0          3      6         770              0
# 3      1.0000           0     0          5      7        1050            910
# 4      1.0000           0     0          3      8        1680              0
# ...       ...         ...   ...        ...    ...         ...            ...
# 21592  3.0000           0     0          3      8        1530              0
# 21593  2.0000           0     0          3      8        2310              0
# 21594  2.0000           0     0          3      7        1020              0
# 21595  2.0000           0     0          3      8        1600              0
# 21596  2.0000           0     0          3      7        1020              0
#
#        yr_built  yr_renovated  zipcode     lat      long  sqft_living15  \
# 0          1955             0    98178 47.5112 -122.2570           1340
# 1          1951          1991    98125 47.7210 -122.3190           1690
# 2          1933             0    98028 47.7379 -122.2330           2720
# 3          1965             0    98136 47.5208 -122.3930           1360
# 4          1987             0    98074 47.6168 -122.0450           1800
# ...         ...           ...      ...     ...       ...            ...
# 21592      2009             0    98103 47.6993 -122.3460           1530
# 21593      2014             0    98146 47.5107 -122.3620           1830
# 21594      2009             0    98144 47.5944 -122.2990           1020
# 21595      2004             0    98027 47.5345 -122.0690           1410
# 21596      2008             0    98144 47.5941 -122.2990           1020
#
#        sqft_lot15   price
# 0            5650  221900
# 1            7639  538000
# 2            8062  180000
# 3            5000  604000
# 4            7503  510000
# ...           ...     ...
# 21592        1509  360000
# 21593        7200  400000
# 21594        2007  402101
# 21595        1287  400000
# 21596        1357  325000
#
# [21597 rows x 21 columns]

# %% [markdown]
# ### Columns type

# %%
df.dtypes
# Out:
# id                        int64
# date             datetime64[ns]
# bedrooms                  int64
# bathrooms               float64
# sqft_living               int64
# sqft_lot                  int64
# floors                  float64
# waterfront                int64
# view                      int64
# condition                 int64
# grade                     int64
# sqft_above                int64
# sqft_basement             int64
# yr_built                  int64
# yr_renovated              int64
# zipcode                   int64
# lat                     float64
# long                    float64
# sqft_living15             int64
# sqft_lot15                int64
# price                     int64
# dtype: object

# %% [markdown]
# ### Checking NULL values

# %%
display(df.isnull().sum())
# Out:
# id               0
# date             0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# price            0
# dtype: int64

# %% [markdown]
# **Drop irrelevant or redundant columns**

# %%
# As zipcode already provides the location of the propreties and is easier to work with 
##(compared to the exact coordinates), lat and lon are droped. 
df = df.drop(['id','lat', 'long'], axis=1)
df
# Out:
#             date  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0     2014-10-13         3     1.0000         1180      5650  1.0000
# 1     2014-12-09         3     2.2500         2570      7242  2.0000
# 2     2015-02-25         2     1.0000          770     10000  1.0000
# 3     2014-12-09         4     3.0000         1960      5000  1.0000
# 4     2015-02-18         3     2.0000         1680      8080  1.0000
# ...          ...       ...        ...          ...       ...     ...
# 21592 2014-05-21         3     2.5000         1530      1131  3.0000
# 21593 2015-02-23         4     2.5000         2310      5813  2.0000
# 21594 2014-06-23         2     0.7500         1020      1350  2.0000
# 21595 2015-01-16         3     2.5000         1600      2388  2.0000
# 21596 2014-10-15         2     0.7500         1020      1076  2.0000
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0               0     0          3      7        1180              0
# 1               0     0          3      7        2170            400
# 2               0     0          3      6         770              0
# 3               0     0          5      7        1050            910
# 4               0     0          3      8        1680              0
# ...           ...   ...        ...    ...         ...            ...
# 21592           0     0          3      8        1530              0
# 21593           0     0          3      8        2310              0
# 21594           0     0          3      7        1020              0
# 21595           0     0          3      8        1600              0
# 21596           0     0          3      7        1020              0
#
#        yr_built  yr_renovated  zipcode  sqft_living15  sqft_lot15   price
# 0          1955             0    98178           1340        5650  221900
# 1          1951          1991    98125           1690        7639  538000
# 2          1933             0    98028           2720        8062  180000
# 3          1965             0    98136           1360        5000  604000
# 4          1987             0    98074           1800        7503  510000
# ...         ...           ...      ...            ...         ...     ...
# 21592      2009             0    98103           1530        1509  360000
# 21593      2014             0    98146           1830        7200  400000
# 21594      2009             0    98144           1020        2007  402101
# 21595      2004             0    98027           1410        1287  400000
# 21596      2008             0    98144           1020        1357  325000
#
# [21597 rows x 18 columns]

# %% [markdown]
# ### Checking Columns

# %%
df['bedrooms'].value_counts()
# Out:
# 3     9824
# 4     6882
# 2     2760
# 5     1601
# 6      272
# 1      196
# 7       38
# 8       13
# 9        6
# 10       3
# 11       1
# 33       1
# Name: bedrooms, dtype: int64

# %%
# Drop one extreme value, 33 rooms is probably a typo considering the rest of the information on the row
df.loc[df['bedrooms'] == 33]
# Out:
#             date  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 15856 2014-06-25        33     1.7500         1620      6000  1.0000
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 15856           0     0          5      7        1040            580
#
#        yr_built  yr_renovated  zipcode  sqft_living15  sqft_lot15   price
# 15856      1947             0    98103           1330        4700  640000

# %%
df = df.drop(15856).reset_index(drop=True)

# %%
df
# Out:
#             date  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0     2014-10-13         3     1.0000         1180      5650  1.0000
# 1     2014-12-09         3     2.2500         2570      7242  2.0000
# 2     2015-02-25         2     1.0000          770     10000  1.0000
# 3     2014-12-09         4     3.0000         1960      5000  1.0000
# 4     2015-02-18         3     2.0000         1680      8080  1.0000
# ...          ...       ...        ...          ...       ...     ...
# 21591 2014-05-21         3     2.5000         1530      1131  3.0000
# 21592 2015-02-23         4     2.5000         2310      5813  2.0000
# 21593 2014-06-23         2     0.7500         1020      1350  2.0000
# 21594 2015-01-16         3     2.5000         1600      2388  2.0000
# 21595 2014-10-15         2     0.7500         1020      1076  2.0000
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0               0     0          3      7        1180              0
# 1               0     0          3      7        2170            400
# 2               0     0          3      6         770              0
# 3               0     0          5      7        1050            910
# 4               0     0          3      8        1680              0
# ...           ...   ...        ...    ...         ...            ...
# 21591           0     0          3      8        1530              0
# 21592           0     0          3      8        2310              0
# 21593           0     0          3      7        1020              0
# 21594           0     0          3      8        1600              0
# 21595           0     0          3      7        1020              0
#
#        yr_built  yr_renovated  zipcode  sqft_living15  sqft_lot15   price
# 0          1955             0    98178           1340        5650  221900
# 1          1951          1991    98125           1690        7639  538000
# 2          1933             0    98028           2720        8062  180000
# 3          1965             0    98136           1360        5000  604000
# 4          1987             0    98074           1800        7503  510000
# ...         ...           ...      ...            ...         ...     ...
# 21591      2009             0    98103           1530        1509  360000
# 21592      2014             0    98146           1830        7200  400000
# 21593      2009             0    98144           1020        2007  402101
# 21594      2004             0    98027           1410        1287  400000
# 21595      2008             0    98144           1020        1357  325000
#
# [21596 rows x 18 columns]

# %%
df['bathrooms'].value_counts()
# Out:
# 2.5000    5377
# 1.0000    3851
# 1.7500    3047
# 2.2500    2047
# 2.0000    1930
# 1.5000    1445
# 2.7500    1185
# 3.0000     753
# 3.5000     731
# 3.2500     589
# 3.7500     155
# 4.0000     136
# 4.5000     100
# 4.2500      79
# 0.7500      71
# 4.7500      23
# 5.0000      21
# 5.2500      13
# 5.5000      10
# 1.2500       9
# 6.0000       6
# 0.5000       4
# 5.7500       4
# 6.7500       2
# 8.0000       2
# 6.2500       2
# 6.5000       2
# 7.5000       1
# 7.7500       1
# Name: bathrooms, dtype: int64

# %%
df['floors'].value_counts()
# Out:
# 1.0000    10672
# 2.0000     8235
# 1.5000     1910
# 3.0000      611
# 2.5000      161
# 3.5000        7
# Name: floors, dtype: int64

# %%
df['waterfront'].dtypes
# Out:
# dtype('int64')

# %%
# Values from 0 to 4 indicating how nice the view is 
df['view'].value_counts()
# Out:
# 0    19474
# 2      961
# 3      510
# 1      332
# 4      319
# Name: view, dtype: int64

# %%
df['condition'].value_counts()
# Out:
# 3    14020
# 4     5677
# 5     1700
# 2      170
# 1       29
# Name: condition, dtype: int64

# %%
df['grade'].value_counts()
# Out:
# 7     8973
# 8     6065
# 9     2615
# 6     2038
# 10    1134
# 11     399
# 5      242
# 12      89
# 4       27
# 13      13
# 3        1
# Name: grade, dtype: int64

# %%
df['yr_built'].value_counts()
# Out:
# 2014    559
# 2006    453
# 2005    450
# 2004    433
# 2003    420
#        ...
# 1933     30
# 1901     29
# 1902     27
# 1935     24
# 1934     21
# Name: yr_built, Length: 116, dtype: int64

# %%
df['yr_renovated'].value_counts()
# Out:
# 0       20682
# 2014       91
# 2013       37
# 2003       36
# 2005       35
#         ...
# 1951        1
# 1959        1
# 1948        1
# 1954        1
# 1944        1
# Name: yr_renovated, Length: 70, dtype: int64

# %%
df['zipcode'].value_counts()
# Out:
# 98103    601
# 98038    589
# 98115    583
# 98052    574
# 98117    553
#         ...
# 98102    104
# 98010    100
# 98024     80
# 98148     57
# 98039     50
# Name: zipcode, Length: 70, dtype: int64

# %%
df['sqft_living15'].value_counts()
# Out:
# 1540    197
# 1440    195
# 1560    192
# 1500    180
# 1460    169
#        ...
# 3736      1
# 4950      1
# 2728      1
# 4740      1
# 2927      1
# Name: sqft_living15, Length: 777, dtype: int64

# %%
df['sqft_lot15'].value_counts()
# Out:
# 5000     427
# 4000     356
# 6000     288
# 7200     210
# 4800     145
#         ...
# 10170      1
# 10573      1
# 11477      1
# 1449       1
# 2007       1
# Name: sqft_lot15, Length: 8682, dtype: int64

# %%
df['price'].describe()
# Out:
# count     21596.0000
# mean     540291.9568
# std      367376.0193
# min       78000.0000
# 25%      322000.0000
# 50%      450000.0000
# 75%      645000.0000
# max     7700000.0000
# Name: price, dtype: float64

# %% [markdown]
# Understanding the difference between sqft_living' and 'sqft_living15.
# sqft_living15 - The square footage of interior housing living space for the nearest 15 neighbors

# %%
#Comparing the size of the houses to the average of the living space for the nearest 15 neighbors
# Would make sense to assamble by location later on. 
df_size = df.filter(['sqft_living', 'sqft_above', 'sqft_lot', 'sqft_living15', 'sqft_lot15'])
df_size
# Out:
#        sqft_living  sqft_above  sqft_lot  sqft_living15  sqft_lot15
# 0             1180        1180      5650           1340        5650
# 1             2570        2170      7242           1690        7639
# 2              770         770     10000           2720        8062
# 3             1960        1050      5000           1360        5000
# 4             1680        1680      8080           1800        7503
# ...            ...         ...       ...            ...         ...
# 21591         1530        1530      1131           1530        1509
# 21592         2310        2310      5813           1830        7200
# 21593         1020        1020      1350           1020        2007
# 21594         1600        1600      2388           1410        1287
# 21595         1020        1020      1076           1020        1357
#
# [21596 rows x 5 columns]

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Transform yr_built

# %%
# Transform yr_built into age of the building

# %%
df['yr_built']= list(map(lambda x: 2015-x, df['yr_built']))

# %%
df['yr_built']
# Out:
# 0        60
# 1        64
# 2        82
# 3        50
# 4        28
#          ..
# 21591     6
# 21592     1
# 21593     6
# 21594    11
# 21595     7
# Name: yr_built, Length: 21596, dtype: int64

# %%
df.rename(columns = {'yr_built' : 'age_build'}, inplace=True)

# %%
df
# Out:
#             date  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0     2014-10-13         3     1.0000         1180      5650  1.0000
# 1     2014-12-09         3     2.2500         2570      7242  2.0000
# 2     2015-02-25         2     1.0000          770     10000  1.0000
# 3     2014-12-09         4     3.0000         1960      5000  1.0000
# 4     2015-02-18         3     2.0000         1680      8080  1.0000
# ...          ...       ...        ...          ...       ...     ...
# 21591 2014-05-21         3     2.5000         1530      1131  3.0000
# 21592 2015-02-23         4     2.5000         2310      5813  2.0000
# 21593 2014-06-23         2     0.7500         1020      1350  2.0000
# 21594 2015-01-16         3     2.5000         1600      2388  2.0000
# 21595 2014-10-15         2     0.7500         1020      1076  2.0000
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0               0     0          3      7        1180              0
# 1               0     0          3      7        2170            400
# 2               0     0          3      6         770              0
# 3               0     0          5      7        1050            910
# 4               0     0          3      8        1680              0
# ...           ...   ...        ...    ...         ...            ...
# 21591           0     0          3      8        1530              0
# 21592           0     0          3      8        2310              0
# 21593           0     0          3      7        1020              0
# 21594           0     0          3      8        1600              0
# 21595           0     0          3      7        1020              0
#
#        age_build  yr_renovated  zipcode  sqft_living15  sqft_lot15   price
# 0             60             0    98178           1340        5650  221900
# 1             64          1991    98125           1690        7639  538000
# 2             82             0    98028           2720        8062  180000
# 3             50             0    98136           1360        5000  604000
# 4             28             0    98074           1800        7503  510000
# ...          ...           ...      ...            ...         ...     ...
# 21591          6             0    98103           1530        1509  360000
# 21592          1             0    98146           1830        7200  400000
# 21593          6             0    98144           1020        2007  402101
# 21594         11             0    98027           1410        1287  400000
# 21595          7             0    98144           1020        1357  325000
#
# [21596 rows x 18 columns]

# %% [markdown]
# ### Changing columns type into categorical variables

# %%
df['waterfront'] = pd.Categorical(df['waterfront']) # waterfron view yes= 1 or no= 0 
df['view'] = pd.Categorical(df['view'])
df['condition'] = pd.Categorical(df['condition'])
df['grade'] = pd.Categorical(df['grade'])
df['bathrooms'] = pd.Categorical(df['bathrooms'])
df['bedrooms'] = pd.Categorical(df['bedrooms'])
df['floors'] = pd.Categorical(df['floors'])
df['yr_renovated'] = pd.Categorical(df['yr_renovated'])
df['age_build'] = pd.Categorical(df['age_build'])

# %%
df.dtypes
# Out:
# date             datetime64[ns]
# bedrooms               category
# bathrooms              category
# sqft_living               int64
# sqft_lot                  int64
# floors                 category
# waterfront             category
# view                   category
# condition              category
# grade                  category
# sqft_above                int64
# sqft_basement             int64
# age_build              category
# yr_renovated           category
# zipcode                   int64
# sqft_living15             int64
# sqft_lot15                int64
# price                     int64
# dtype: object

# %%
categorical = df.select_dtypes(include = ['category'])
categorical
# Out:
#       bedrooms bathrooms floors waterfront view condition grade age_build  \
# 0            3    1.0000 1.0000          0    0         3     7        60
# 1            3    2.2500 2.0000          0    0         3     7        64
# 2            2    1.0000 1.0000          0    0         3     6        82
# 3            4    3.0000 1.0000          0    0         5     7        50
# 4            3    2.0000 1.0000          0    0         3     8        28
# ...        ...       ...    ...        ...  ...       ...   ...       ...
# 21591        3    2.5000 3.0000          0    0         3     8         6
# 21592        4    2.5000 2.0000          0    0         3     8         1
# 21593        2    0.7500 2.0000          0    0         3     7         6
# 21594        3    2.5000 2.0000          0    0         3     8        11
# 21595        2    0.7500 2.0000          0    0         3     7         7
#
#       yr_renovated
# 0                0
# 1             1991
# 2                0
# 3                0
# 4                0
# ...            ...
# 21591            0
# 21592            0
# 21593            0
# 21594            0
# 21595            0
#
# [21596 rows x 9 columns]

# %%
categorical.isnull().sum()
# Out:
# bedrooms        0
# bathrooms       0
# floors          0
# waterfront      0
# view            0
# condition       0
# grade           0
# age_build       0
# yr_renovated    0
# dtype: int64

# %% [markdown]
# ### Distributions of numeric features

# %% [markdown]
# **Filtering the numerical variables:**

# %%
numerical = df.select_dtypes(include = ['int64', 'float'])
numerical
# Out:
#        sqft_living  sqft_lot  sqft_above  sqft_basement  zipcode  \
# 0             1180      5650        1180              0    98178
# 1             2570      7242        2170            400    98125
# 2              770     10000         770              0    98028
# 3             1960      5000        1050            910    98136
# 4             1680      8080        1680              0    98074
# ...            ...       ...         ...            ...      ...
# 21591         1530      1131        1530              0    98103
# 21592         2310      5813        2310              0    98146
# 21593         1020      1350        1020              0    98144
# 21594         1600      2388        1600              0    98027
# 21595         1020      1076        1020              0    98144
#
#        sqft_living15  sqft_lot15   price
# 0               1340        5650  221900
# 1               1690        7639  538000
# 2               2720        8062  180000
# 3               1360        5000  604000
# 4               1800        7503  510000
# ...              ...         ...     ...
# 21591           1530        1509  360000
# 21592           1830        7200  400000
# 21593           1020        2007  402101
# 21594           1410        1287  400000
# 21595           1020        1357  325000
#
# [21596 rows x 8 columns]

# %%
# Plot histogram of numerical features 
numerical.hist(figsize=(20,20), xrot=-45)
plt.show()

# %% [markdown]
# **Observations**:
# - Most of the sqft_basement are a 0, meaning probably there's no basement. Change to categorical.

# %%
#Changing sqft_basement into categorical variable, with basement0 1, without =0

# %%
df["sqft_basement"] = np.where (df["sqft_basement"] != 0, 1, df["sqft_basement"])
df.sqft_basement.value_counts()
# Out:
# 0    13110
# 1     8486
# Name: sqft_basement, dtype: int64

# %%
df.rename(columns = {'sqft_basement' : 'basement'}, inplace=True)

# %%
df
# Out:
#             date bedrooms bathrooms  sqft_living  sqft_lot floors waterfront  \
# 0     2014-10-13        3    1.0000         1180      5650 1.0000          0
# 1     2014-12-09        3    2.2500         2570      7242 2.0000          0
# 2     2015-02-25        2    1.0000          770     10000 1.0000          0
# 3     2014-12-09        4    3.0000         1960      5000 1.0000          0
# 4     2015-02-18        3    2.0000         1680      8080 1.0000          0
# ...          ...      ...       ...          ...       ...    ...        ...
# 21591 2014-05-21        3    2.5000         1530      1131 3.0000          0
# 21592 2015-02-23        4    2.5000         2310      5813 2.0000          0
# 21593 2014-06-23        2    0.7500         1020      1350 2.0000          0
# 21594 2015-01-16        3    2.5000         1600      2388 2.0000          0
# 21595 2014-10-15        2    0.7500         1020      1076 2.0000          0
#
#       view condition grade  sqft_above  basement age_build yr_renovated  \
# 0        0         3     7        1180         0        60            0
# 1        0         3     7        2170         1        64         1991
# 2        0         3     6         770         0        82            0
# 3        0         5     7        1050         1        50            0
# 4        0         3     8        1680         0        28            0
# ...    ...       ...   ...         ...       ...       ...          ...
# 21591    0         3     8        1530         0         6            0
# 21592    0         3     8        2310         0         1            0
# 21593    0         3     7        1020         0         6            0
# 21594    0         3     8        1600         0        11            0
# 21595    0         3     7        1020         0         7            0
#
#        zipcode  sqft_living15  sqft_lot15   price
# 0        98178           1340        5650  221900
# 1        98125           1690        7639  538000
# 2        98028           2720        8062  180000
# 3        98136           1360        5000  604000
# 4        98074           1800        7503  510000
# ...        ...            ...         ...     ...
# 21591    98103           1530        1509  360000
# 21592    98146           1830        7200  400000
# 21593    98144           1020        2007  402101
# 21594    98027           1410        1287  400000
# 21595    98144           1020        1357  325000
#
# [21596 rows x 18 columns]

# %%
df['basement'] = pd.Categorical(df['basement'])

# %%
# Adding basement to categorical variables
categorical = df.select_dtypes(include = ['category'])
categorical
# Out:
#       bedrooms bathrooms floors waterfront view condition grade basement  \
# 0            3    1.0000 1.0000          0    0         3     7        0
# 1            3    2.2500 2.0000          0    0         3     7        1
# 2            2    1.0000 1.0000          0    0         3     6        0
# 3            4    3.0000 1.0000          0    0         5     7        1
# 4            3    2.0000 1.0000          0    0         3     8        0
# ...        ...       ...    ...        ...  ...       ...   ...      ...
# 21591        3    2.5000 3.0000          0    0         3     8        0
# 21592        4    2.5000 2.0000          0    0         3     8        0
# 21593        2    0.7500 2.0000          0    0         3     7        0
# 21594        3    2.5000 2.0000          0    0         3     8        0
# 21595        2    0.7500 2.0000          0    0         3     7        0
#
#       age_build yr_renovated
# 0            60            0
# 1            64         1991
# 2            82            0
# 3            50            0
# 4            28            0
# ...         ...          ...
# 21591         6            0
# 21592         1            0
# 21593         6            0
# 21594        11            0
# 21595         7            0
#
# [21596 rows x 10 columns]

# %%
numerical = df.select_dtypes(include = ['int64', 'float'])
numerical
# Out:
#        sqft_living  sqft_lot  sqft_above  zipcode  sqft_living15  sqft_lot15  \
# 0             1180      5650        1180    98178           1340        5650
# 1             2570      7242        2170    98125           1690        7639
# 2              770     10000         770    98028           2720        8062
# 3             1960      5000        1050    98136           1360        5000
# 4             1680      8080        1680    98074           1800        7503
# ...            ...       ...         ...      ...            ...         ...
# 21591         1530      1131        1530    98103           1530        1509
# 21592         2310      5813        2310    98146           1830        7200
# 21593         1020      1350        1020    98144           1020        2007
# 21594         1600      2388        1600    98027           1410        1287
# 21595         1020      1076        1020    98144           1020        1357
#
#         price
# 0      221900
# 1      538000
# 2      180000
# 3      604000
# 4      510000
# ...       ...
# 21591  360000
# 21592  400000
# 21593  402101
# 21594  400000
# 21595  325000
#
# [21596 rows x 7 columns]

# %% [markdown]
# ### Distribution of categorical variables

# %%
plt.figure(figsize=(25,20))
for i, column in enumerate(categorical,1):
    plt.subplot(4,3,i)
    sns.countplot(categorical[column])
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# **Observations**
# - majority of properties has no view to waterfront
# - majority of properties has a very low score in 'view'
# - most of properties has an average condition
# - distribution of grade scoring of properties is near to normal
# - most properties have upto 3 or 4 bedrooms

# %% [markdown]
# ### Correlation of numerical variables (with price)

# %%
corr = numerical.corr()
fig, ax = plt.subplots(figsize=(15,15))
mask=np.zeros_like(numerical.corr())
mask[np.triu_indices_from(mask)]=True
sns.heatmap(corr,
            cmap='seismic',
            mask=mask,
            center=0,
            annot=True,
            ax=ax)
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Observations**:
# - sqft_above > 0.80 in relation with price
# - sqft_living15 and sqft_living = 0.76
# - sqft_lot and sqft_lot15 = 0.72
# - Zipcode should be transformed

# %% [markdown]
# ### Correlation of numerical variables (without price)

# %%
numerical_2 = numerical.iloc[:, :-1]
numerical_2
# Out:
#        sqft_living  sqft_lot  sqft_above  zipcode  sqft_living15  sqft_lot15
# 0             1180      5650        1180    98178           1340        5650
# 1             2570      7242        2170    98125           1690        7639
# 2              770     10000         770    98028           2720        8062
# 3             1960      5000        1050    98136           1360        5000
# 4             1680      8080        1680    98074           1800        7503
# ...            ...       ...         ...      ...            ...         ...
# 21591         1530      1131        1530    98103           1530        1509
# 21592         2310      5813        2310    98146           1830        7200
# 21593         1020      1350        1020    98144           1020        2007
# 21594         1600      2388        1600    98027           1410        1287
# 21595         1020      1076        1020    98144           1020        1357
#
# [21596 rows x 6 columns]

# %%
corr_2 = numerical_2.corr()
fig, ax = plt.subplots(figsize=(15,15))
mask = np.zeros_like(numerical_2.corr())
mask[np.triu_indices_from(mask)]=True
sns.heatmap(corr_2,
            cmap='seismic',
            mask=mask,
            center=0,
            annot=True,
            ax=ax)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Highly Correlated Columns

# %%
corr_matrix = numerical_2.corr().abs()
upper_triangle = corr_matrix.where(np.triu(np.ones(corr_matrix.shape),k=1).astype(bool))
[column for column in upper_triangle.columns if any(upper_triangle[column] > 0.80)]
# Out:
# ['sqft_above']

# %% [markdown]
# ### Drop the highly correlate variable

# %%
# sqft_above and sqft_living > 0.80

# %%
numerical_2.drop(['sqft_above'],axis=1,inplace=True)
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
numerical_2
# Out:
#        sqft_living  sqft_lot  zipcode  sqft_living15  sqft_lot15
# 0             1180      5650    98178           1340        5650
# 1             2570      7242    98125           1690        7639
# 2              770     10000    98028           2720        8062
# 3             1960      5000    98136           1360        5000
# 4             1680      8080    98074           1800        7503
# ...            ...       ...      ...            ...         ...
# 21591         1530      1131    98103           1530        1509
# 21592         2310      5813    98146           1830        7200
# 21593         1020      1350    98144           1020        2007
# 21594         1600      2388    98027           1410        1287
# 21595         1020      1076    98144           1020        1357
#
# [21596 rows x 5 columns]

# %% [markdown]
# ### Correlation of categorical variables with price

# %%
sns.barplot(x = df['waterfront'],y = df['price'])
# Out:
# <AxesSubplot:xlabel='waterfront', ylabel='price'>

# %%
sns.barplot(x = df['view'],y = df['price'])
# Out:
# <AxesSubplot:xlabel='view', ylabel='price'>

# %%
sns.barplot(x = df['condition'],y = df['price'])
# Out:
# <AxesSubplot:xlabel='condition', ylabel='price'>

# %%
sns.barplot(x = df['grade'],y = df['price'])
# Out:
# <AxesSubplot:xlabel='grade', ylabel='price'>

# %%
sns.barplot(x = df['bedrooms'],y = df['price'])
# Out:
# <AxesSubplot:xlabel='bedrooms', ylabel='price'>

# %%
sns.barplot(x = df['bathrooms'],y = df['price'])
plt.gcf().set_size_inches(15,9)

# %%
sns.barplot(x = df['basement'],y = df['price'])
plt.gcf().set_size_inches(8,5)

# %% [markdown]
# #### Bedrooms

# %% [markdown]
# Replacing the values from the bedroom outliers to the maximum value >8 == 9

# %%
categorical['bedrooms'] = categorical['bedrooms'].replace([11,10],9)
categorical['bedrooms'].unique()
# Out:
# /var/folders/mm/gw92vpys6rggjz_4z42s244w0000gn/T/ipykernel_4666/3023704718.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   categorical['bedrooms'] = categorical['bedrooms'].replace([11,10],9)
# [3, 2, 4, 5, 1, 6, 7, 8, 9]
# Categories (9, int64): [1, 2, 3, 4, ..., 6, 7, 8, 9]

# %%
sns.barplot(x = categorical['bedrooms'],y = df['price'])
# Out:
# <AxesSubplot:xlabel='bedrooms', ylabel='price'>

# %% [markdown]
# ### Normalize numerical features ( excluding price)

# %% [markdown]
# sqft_living

# %%
qt = QuantileTransformer(output_distribution = 'normal')
numerical_2['sqft_living'] = qt.fit_transform(numerical_2['sqft_living'].to_numpy().reshape(-1,1))
sns.displot(numerical_2['sqft_living'])
# Out:
# /var/folders/mm/gw92vpys6rggjz_4z42s244w0000gn/T/ipykernel_4666/1664979473.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   numerical_2['sqft_living'] = qt.fit_transform(numerical_2['sqft_living'].to_numpy().reshape(-1,1))

# %% [markdown]
# sqft_living15

# %%
qt = QuantileTransformer(output_distribution = 'normal')
numerical_2['sqft_living15'] = qt.fit_transform(numerical_2['sqft_living15'].to_numpy().reshape(-1,1))
sns.displot(numerical_2['sqft_living15'])
# Out:
# /var/folders/mm/gw92vpys6rggjz_4z42s244w0000gn/T/ipykernel_4666/1975453770.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   numerical_2['sqft_living15'] = qt.fit_transform(numerical_2['sqft_living15'].to_numpy().reshape(-1,1))

# %% [markdown]
# sqft_lot

# %%
qt = QuantileTransformer(output_distribution = 'normal')
numerical_2['sqft_lot'] = qt.fit_transform(numerical_2['sqft_lot'].to_numpy().reshape(-1,1))
sns.displot(numerical_2['sqft_lot'])
# Out:
# /var/folders/mm/gw92vpys6rggjz_4z42s244w0000gn/T/ipykernel_4666/2662698753.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   numerical_2['sqft_lot'] = qt.fit_transform(numerical_2['sqft_lot'].to_numpy().reshape(-1,1))

# %% [markdown]
# sqft_lot15

# %%
qt = QuantileTransformer(output_distribution = 'normal')
numerical_2['sqft_lot15'] = qt.fit_transform(numerical_2['sqft_lot15'].to_numpy().reshape(-1,1))
sns.displot(numerical_2['sqft_lot15'])
# Out:
# /var/folders/mm/gw92vpys6rggjz_4z42s244w0000gn/T/ipykernel_4666/4243214181.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   numerical_2['sqft_lot15'] = qt.fit_transform(numerical_2['sqft_lot15'].to_numpy().reshape(-1,1))

# %% [markdown]
# ## Trial 1: Linear regression only with numerical variables

# %% [markdown]
# #### Xy Split

# %%
X=numerical_2
X
y=numerical.price
y
# Out:
# 0        221900
# 1        538000
# 2        180000
# 3        604000
# 4        510000
#           ...
# 21591    360000
# 21592    400000
# 21593    402101
# 21594    400000
# 21595    325000
# Name: price, Length: 21596, dtype: int64

# %%
X=X._get_numeric_data()
X
# Out:
#        sqft_living  sqft_lot  zipcode  sqft_living15  sqft_lot15
# 0          -1.1094   -0.5178    98178        -1.0379     -0.5181
# 1           0.6943   -0.1155    98125        -0.2471      0.0075
# 2          -2.1317    0.5628    98028         1.0641      0.1541
# 3           0.0515   -0.7185    98136        -0.9856     -0.7447
# 4          -0.2940    0.1280    98074        -0.0628     -0.0404
# ...            ...       ...      ...            ...         ...
# 21591      -0.5092   -2.1322    98103        -0.5731     -1.8316
# 21592       0.4362   -0.4751    98146        -0.0125     -0.1664
# 21593      -1.4285   -1.8373    98144        -2.0431     -1.6441
# 21594      -0.4061   -1.5155    98027        -0.8625     -2.0680
# 21595      -1.4285   -2.2208    98144        -2.0431     -1.9548
#
# [21596 rows x 5 columns]

# %% [markdown]
# #### Data Splitting

# %%
X_train, X_test, y_train, y_test=train_test_split(X, y, test_size=.30,random_state=123)

# %% [markdown]
# #### Standardize

# %%
std_scaler = StandardScaler().fit(X_train) 

X_train_scaled = std_scaler.transform(X_train)

# %%
X_test_scaled=std_scaler.transform(X_test)

# %%
print(X_train_scaled)
print("--------")
print(X_test_scaled)
# Out:
# [[-0.71707153  0.41865299  0.52695717 -0.41855798  0.27814248]
#  [ 0.54640315  0.37730395 -1.39808504 -0.88431417 -0.16690314]
#  [ 0.1867116   0.81873396 -0.07111419  0.37987618  0.9915377 ]
#  ...
#  [-0.16726225 -0.08728358 -0.74394448 -0.6149564   0.0020762 ]
#  [ 0.00642335  0.49158368 -0.8747726  -0.64090562  0.51783934]
#  [-0.82856292 -1.80782357  0.71385448 -0.45577345 -0.81851476]]
# --------
# [[ 0.71975034  0.3302575  -0.37014988  0.88311427  0.34810092]
#  [-0.58388885 -1.82944958  1.08764908 -0.52357866 -1.96006164]
#  [-0.50968445 -2.37422485  0.47088798 -0.57161943 -2.07731091]
#  ...
#  [-1.4278584   0.08286582  0.52695717 -2.11501665 -0.18381468]
#  [-0.21703882 -0.09885053  1.68572045 -0.16316295 -0.01723105]
#  [ 1.42220091 -0.30117319  1.08764908 -0.14795428 -0.29942452]]

# %% [markdown]
# #### Regression

# %%
X_train_const_scaled = sm.add_constant(X_train_scaled) # adding a constant

model = sm.OLS(y_train, X_train_const_scaled).fit()
predictions_train = model.predict(X_train_const_scaled) 

X_test_const_scaled = sm.add_constant(X_test_scaled) # adding a constant
predictions_test = model.predict(X_test_const_scaled) 
print_model = model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.407
# Model:                            OLS   Adj. R-squared:                  0.407
# Method:                 Least Squares   F-statistic:                     2075.
# Date:                Fri, 11 Feb 2022   Prob (F-statistic):               0.00
# Time:                        12:05:28   Log-Likelihood:            -2.1111e+05
# No. Observations:               15117   AIC:                         4.222e+05
# Df Residuals:                   15111   BIC:                         4.223e+05
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       5.391e+05   2286.670    235.756      0.000    5.35e+05    5.44e+05
# x1          1.805e+05   3456.507     52.226      0.000    1.74e+05    1.87e+05
# x2         -7782.2046   6082.151     -1.280      0.201   -1.97e+04    4139.548
# x3          3.403e+04   2452.942     13.873      0.000    2.92e+04    3.88e+04
# x4          7.988e+04   3563.913     22.414      0.000    7.29e+04    8.69e+04
# x5         -1.487e+04   6089.539     -2.442      0.015   -2.68e+04   -2932.196
# ==============================================================================
# Omnibus:                    13562.798   Durbin-Watson:                   1.994
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1065557.806
# Skew:                           4.000   Prob(JB):                         0.00
# Kurtosis:                      43.345   Cond. No.                         6.09
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# #### Model validation

# %%
#using sklearn
model=LinearRegression()    # model
model.fit(X_train_scaled, y_train)   # model train
# Out:
# LinearRegression()

# %%
model.coef_ #gives you per column the slope (alpha)
# Out:
# array([180520.39569449,  -7782.20460059,  34028.45782476,  79882.2714608 ,
#        -14868.42903328])

# %%
model.intercept_ #gives the optimal slope
# Out:
# 539096.3280412789

# %%
R2_test = model.score(X_test_scaled,y_test) # measure R2
R2_test
# Out:
# 0.3982104617336951

# %%
# Making prediction
y_pred = model.predict(X_test_scaled)
y_pred
# Out:
# array([719229.64357319, 472259.03876379, 466812.27694754, ...,
#        132406.12815286, 545270.50902455, 827820.45870162])

# %%
y_test
# Out:
# 14863     392000
# 2277      418000
# 21578     520000
# 18669    1050000
# 21453     249000
#           ...
# 12811     291970
# 12288     741000
# 6556      269000
# 16310     180000
# 1050      850000
# Name: price, Length: 6479, dtype: int64

# %%
result=pd.DataFrame({"y_test":y_test,"y_pred":y_pred})

# %%
# Make an scatter plot y_pred vs y

fig, ax = plt.subplots(1,3,figsize=(14,4))
ax[0].plot(y_pred, y_test, 'o')
ax[0].set_xlabel("y_test")
ax[0].set_ylabel("y_pred")
ax[0].set_title("Test Set -Predicted vs real")

# Get a histogram of the residuals y - y_pred.  

ax[1].hist(y_test - y_pred)
ax[1].set_xlabel("Test y-y_pred")
ax[1].set_title("Test Set Residual histogram")

ax[2].plot(y_pred,y_test - y_pred,"o")
ax[2].set_xlabel("predited")
ax[2].set_ylabel("residuals")
ax[2].set_title("Residuals by Predicted")
ax[2].plot(y_pred,np.zeros(len(y_pred)),linestyle='dashed')

# %%
# The line is not straight and the distribution doesn't resemble a normal distribution.

# %%
sns.regplot(x='y_pred',y='y_test', data=result, scatter_kws={"color": "red"}, line_kws={"color": "black"})
# Out:
# <AxesSubplot:xlabel='y_pred', ylabel='y_test'>

# %% [markdown]
# #### Error metrics

# %%
print(mse(y_test,y_pred))
print(mae(y_test,y_pred))
# Out:
# 83580328540.4141
# 180266.80750623503

# %% [markdown]
# #### Features Importance

# %%
features_importances = pd.DataFrame(data={
    'Attribute': X_train.columns,
    'Importance': abs(model.coef_)
})
features_importances = features_importances.sort_values(by='Importance', ascending=False)
features_importances
# Out:
#        Attribute  Importance
# 0    sqft_living 180520.3957
# 3  sqft_living15  79882.2715
# 2        zipcode  34028.4578
# 4     sqft_lot15  14868.4290
# 1       sqft_lot   7782.2046

# %% [markdown]
# we can notice that the sqft_living and sqft_living 15 are the most relevant

# %% [markdown]
# ## Trial 2: Linear regression with categorical and numerical ( with transformed zipcode)

# %% [markdown]
# ### Transform zipcode

# %%
# Grouping on the zipcodes according to the average price.  
price_zip_mean = df.groupby(['zipcode'])['price'].mean()
price_zip_mean.sort_values(ascending=False)
# Out:
# zipcode
# 98039   2161300.0000
# 98004   1356523.9905
# 98040   1194873.6383
# 98112   1096239.0074
# 98102    899607.6731
#             ...
# 98148    284908.5965
# 98001    281194.8698
# 98032    251296.2400
# 98168    240328.3717
# 98002    234284.0352
# Name: price, Length: 70, dtype: float64

# %%
price_zip = df.groupby(['zipcode'])['price'].mean()
pz = price_zip.sort_values(ascending=False).reset_index()
pz
# Out:
#     zipcode        price
# 0     98039 2161300.0000
# 1     98004 1356523.9905
# 2     98040 1194873.6383
# 3     98112 1096239.0074
# 4     98102  899607.6731
# ..      ...          ...
# 65    98148  284908.5965
# 66    98001  281194.8698
# 67    98032  251296.2400
# 68    98168  240328.3717
# 69    98002  234284.0352
#
# [70 rows x 2 columns]

# %%
#Assigning a zipcode group per quantile from the average of price
Q1 = np.percentile(pz['price'], 25)
Q2 = np.percentile(pz['price'], 50)
Q3 = np.percentile(pz['price'], 75)
Q4 = np.percentile(pz['price'], 100)

# %%
pz['quantile_zip'] = "1"
pz['quantile_zip'] = np.where(pz['price'] >= Q1, "2", pz['quantile_zip'])
pz['quantile_zip'] = np.where(pz['price'] >= Q2, "3", pz['quantile_zip'])
pz['quantile_zip'] = np.where(pz['price'] >= Q3, "4", pz['quantile_zip'])

# %%
#Including a new column on the df assigning one of the 4 quantile groups to each property corresponding to its saleprice. 
df = pd.merge(df, pz[['zipcode', 'quantile_zip']], on='zipcode', how='left', sort=False)

# %%
df
# Out:
#             date bedrooms bathrooms  sqft_living  sqft_lot floors waterfront  \
# 0     2014-10-13        3    1.0000         1180      5650 1.0000          0
# 1     2014-12-09        3    2.2500         2570      7242 2.0000          0
# 2     2015-02-25        2    1.0000          770     10000 1.0000          0
# 3     2014-12-09        4    3.0000         1960      5000 1.0000          0
# 4     2015-02-18        3    2.0000         1680      8080 1.0000          0
# ...          ...      ...       ...          ...       ...    ...        ...
# 21591 2014-05-21        3    2.5000         1530      1131 3.0000          0
# 21592 2015-02-23        4    2.5000         2310      5813 2.0000          0
# 21593 2014-06-23        2    0.7500         1020      1350 2.0000          0
# 21594 2015-01-16        3    2.5000         1600      2388 2.0000          0
# 21595 2014-10-15        2    0.7500         1020      1076 2.0000          0
#
#       view condition grade  sqft_above basement age_build yr_renovated  \
# 0        0         3     7        1180        0        60            0
# 1        0         3     7        2170        1        64         1991
# 2        0         3     6         770        0        82            0
# 3        0         5     7        1050        1        50            0
# 4        0         3     8        1680        0        28            0
# ...    ...       ...   ...         ...      ...       ...          ...
# 21591    0         3     8        1530        0         6            0
# 21592    0         3     8        2310        0         1            0
# 21593    0         3     7        1020        0         6            0
# 21594    0         3     8        1600        0        11            0
# 21595    0         3     7        1020        0         7            0
#
#        zipcode  sqft_living15  sqft_lot15   price quantile_zip
# 0        98178           1340        5650  221900            1
# 1        98125           1690        7639  538000            2
# 2        98028           2720        8062  180000            2
# 3        98136           1360        5000  604000            3
# 4        98074           1800        7503  510000            4
# ...        ...            ...         ...     ...          ...
# 21591    98103           1530        1509  360000            3
# 21592    98146           1830        7200  400000            2
# 21593    98144           1020        2007  402101            3
# 21594    98027           1410        1287  400000            3
# 21595    98144           1020        1357  325000            3
#
# [21596 rows x 19 columns]

# %%
df.drop(['sqft_above','date','zipcode'], axis=1, inplace=True)
df
# Out:
#       bedrooms bathrooms  sqft_living  sqft_lot floors waterfront view  \
# 0            3    1.0000         1180      5650 1.0000          0    0
# 1            3    2.2500         2570      7242 2.0000          0    0
# 2            2    1.0000          770     10000 1.0000          0    0
# 3            4    3.0000         1960      5000 1.0000          0    0
# 4            3    2.0000         1680      8080 1.0000          0    0
# ...        ...       ...          ...       ...    ...        ...  ...
# 21591        3    2.5000         1530      1131 3.0000          0    0
# 21592        4    2.5000         2310      5813 2.0000          0    0
# 21593        2    0.7500         1020      1350 2.0000          0    0
# 21594        3    2.5000         1600      2388 2.0000          0    0
# 21595        2    0.7500         1020      1076 2.0000          0    0
#
#       condition grade basement age_build yr_renovated  sqft_living15  \
# 0             3     7        0        60            0           1340
# 1             3     7        1        64         1991           1690
# 2             3     6        0        82            0           2720
# 3             5     7        1        50            0           1360
# 4             3     8        0        28            0           1800
# ...         ...   ...      ...       ...          ...            ...
# 21591         3     8        0         6            0           1530
# 21592         3     8        0         1            0           1830
# 21593         3     7        0         6            0           1020
# 21594         3     8        0        11            0           1410
# 21595         3     7        0         7            0           1020
#
#        sqft_lot15   price quantile_zip
# 0            5650  221900            1
# 1            7639  538000            2
# 2            8062  180000            2
# 3            5000  604000            3
# 4            7503  510000            4
# ...           ...     ...          ...
# 21591        1509  360000            3
# 21592        7200  400000            2
# 21593        2007  402101            3
# 21594        1287  400000            3
# 21595        1357  325000            3
#
# [21596 rows x 16 columns]

# %% [markdown]
# ### Normalization of numerical features

# %%
#sqft_living
qt = QuantileTransformer(output_distribution = 'normal')
df['sqft_living'] = qt.fit_transform(df['sqft_living'].to_numpy().reshape(-1,1))
sns.displot(df['sqft_living'])

# %%
#sqft_lot
qt = QuantileTransformer(output_distribution = 'normal')
df['sqft_lot'] = qt.fit_transform(df['sqft_lot'].to_numpy().reshape(-1,1))
sns.displot(df['sqft_lot'])

# %%
#sqft_living15
qt = QuantileTransformer(output_distribution = 'normal')
df['sqft_living15'] = qt.fit_transform(df['sqft_living15'].to_numpy().reshape(-1,1))
sns.displot(df['sqft_living15'])

# %%
#sqft_lot15
qt = QuantileTransformer(output_distribution = 'normal')
df['sqft_lot15'] = qt.fit_transform(df['sqft_lot15'].to_numpy().reshape(-1,1))
sns.displot(df['sqft_lot15'])

# %% [markdown]
# ### x/y Splitting

# %%
X2=df.drop('price', axis=1)
X2
# Out:
#       bedrooms bathrooms  sqft_living  sqft_lot floors waterfront view  \
# 0            3    1.0000      -1.1094   -0.5178 1.0000          0    0
# 1            3    2.2500       0.6943   -0.1155 2.0000          0    0
# 2            2    1.0000      -2.1317    0.5628 1.0000          0    0
# 3            4    3.0000       0.0515   -0.7185 1.0000          0    0
# 4            3    2.0000      -0.2940    0.1280 1.0000          0    0
# ...        ...       ...          ...       ...    ...        ...  ...
# 21591        3    2.5000      -0.5092   -2.1322 3.0000          0    0
# 21592        4    2.5000       0.4362   -0.4751 2.0000          0    0
# 21593        2    0.7500      -1.4285   -1.8373 2.0000          0    0
# 21594        3    2.5000      -0.4061   -1.5155 2.0000          0    0
# 21595        2    0.7500      -1.4285   -2.2208 2.0000          0    0
#
#       condition grade basement age_build yr_renovated  sqft_living15  \
# 0             3     7        0        60            0        -1.0379
# 1             3     7        1        64         1991        -0.2471
# 2             3     6        0        82            0         1.0641
# 3             5     7        1        50            0        -0.9856
# 4             3     8        0        28            0        -0.0628
# ...         ...   ...      ...       ...          ...            ...
# 21591         3     8        0         6            0        -0.5731
# 21592         3     8        0         1            0        -0.0125
# 21593         3     7        0         6            0        -2.0431
# 21594         3     8        0        11            0        -0.8625
# 21595         3     7        0         7            0        -2.0431
#
#        sqft_lot15 quantile_zip
# 0         -0.5181            1
# 1          0.0075            2
# 2          0.1541            2
# 3         -0.7447            3
# 4         -0.0404            4
# ...           ...          ...
# 21591     -1.8316            3
# 21592     -0.1664            2
# 21593     -1.6441            3
# 21594     -2.0680            3
# 21595     -1.9548            3
#
# [21596 rows x 15 columns]

# %%
y2=df.price
y2
# Out:
# 0        221900
# 1        538000
# 2        180000
# 3        604000
# 4        510000
#           ...
# 21591    360000
# 21592    400000
# 21593    402101
# 21594    400000
# 21595    325000
# Name: price, Length: 21596, dtype: int64

# %% [markdown]
# ### Data Splitting

# %%
X_train2, X_test2, y_train2, y_test2 = train_test_split(X2, y2, test_size=.30,random_state=123)

# %%
y_train2
# Out:
# 11950    325000
# 17781    389000
# 3405     442000
# 740      360000
# 848      512000
#           ...
# 7763     620000
# 15377    424900
# 17730    272450
# 15725    260000
# 19966    479000
# Name: price, Length: 15117, dtype: int64

# %% [markdown]
# ### Standardize

# %%
std_scaler2 = StandardScaler().fit(X_train2) 

X_train_scaled2 = std_scaler2.transform(X_train2)

# %%
X_test_scaled2 = std_scaler2.transform(X_test2)

# %% [markdown]
# ### Regression

# %%
X_train_const_scaled2 = sm.add_constant(X_train_scaled2) # adding a constant

model2 = sm.OLS(y_train2, X_train_const_scaled2).fit()
predictions_train2 = model2.predict(X_train_const_scaled2) 

X_test_const_scaled2 = sm.add_constant(X_test_scaled2) # adding a constant
predictions_test2 = model2.predict(X_test_const_scaled2) 
print_model2 = model2.summary()
print(print_model2)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.701
# Model:                            OLS   Adj. R-squared:                  0.701
# Method:                 Least Squares   F-statistic:                     2360.
# Date:                Fri, 11 Feb 2022   Prob (F-statistic):               0.00
# Time:                        12:05:43   Log-Likelihood:            -2.0594e+05
# No. Observations:               15117   AIC:                         4.119e+05
# Df Residuals:                   15101   BIC:                         4.120e+05
# Df Model:                          15
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       5.391e+05   1624.382    331.878      0.000    5.36e+05    5.42e+05
# x1          -1.01e+04   2210.829     -4.567      0.000   -1.44e+04   -5763.606
# x2          5.903e+04   2976.692     19.832      0.000    5.32e+04    6.49e+04
# x3          6.794e+04   3924.520     17.313      0.000    6.03e+04    7.56e+04
# x4          1.038e+04   4448.792      2.333      0.020    1659.716    1.91e+04
# x5         -4493.0724   2471.895     -1.818      0.069   -9338.286     352.142
# x6          6.063e+04   1780.650     34.047      0.000    5.71e+04    6.41e+04
# x7          4.409e+04   1889.715     23.331      0.000    4.04e+04    4.78e+04
# x8          1.129e+04   1801.209      6.270      0.000    7762.329    1.48e+04
# x9          1.428e+05   2886.235     49.460      0.000    1.37e+05    1.48e+05
# x10        -5469.0340   2005.369     -2.727      0.006   -9399.801   -1538.267
# x11         8.287e+04   2365.744     35.028      0.000    7.82e+04    8.75e+04
# x12         3217.2705   1745.059      1.844      0.065    -203.256    6637.797
# x13         -283.2663   2706.354     -0.105      0.917   -5588.048    5021.515
# x14        -1.175e+04   4357.695     -2.696      0.007   -2.03e+04   -3207.412
# x15         1.135e+05   1847.467     61.410      0.000     1.1e+05    1.17e+05
# ==============================================================================
# Omnibus:                    14945.757   Durbin-Watson:                   1.995
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          2276201.745
# Skew:                           4.464   Prob(JB):                         0.00
# Kurtosis:                      62.448   Cond. No.                         7.81
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# #### Model validation

# %%
#using sklearn
model2=LinearRegression()    # model
model2.fit(X_train_scaled2, y_train2)   # model train
# Out:
# LinearRegression()

# %%
model2.coef_ #gives you per column the slope (alpha)
# Out:
# array([-10097.09885152,  59033.53052328,  67943.95222373,  10379.88761114,
#         -4493.07237827,  60625.93549183,  44088.36704673,  11292.91729795,
#        142754.54867921,  -5469.03396841,  82867.29406105,   3217.27046052,
#          -283.26633788, -11749.02254112, 113452.96761291])

# %%
R2_test2 = model2.score(X_test_scaled2,y_test2) # measure R2
R2_test2
# Out:
# 0.6755576831309416

# %%
### Making prediction
y_pred2 = model2.predict(X_test_scaled2)
y_pred2
# Out:
# array([412415.35467978, 304883.54284747, 479496.99046194, ...,
#        215813.92851479, 229406.57730848, 707941.84869558])

# %%
y_test2
# Out:
# 14863     392000
# 2277      418000
# 21578     520000
# 18669    1050000
# 21453     249000
#           ...
# 12811     291970
# 12288     741000
# 6556      269000
# 16310     180000
# 1050      850000
# Name: price, Length: 6479, dtype: int64

# %%
result=pd.DataFrame({"y_test":y_test2,"y_pred":y_pred2})

# %%
# Make an scatter plot y_pred vs y

fig, ax = plt.subplots(1,3,figsize=(14,4))
ax[0].plot(y_pred2, y_test2, 'o')
ax[0].set_xlabel("y_test")
ax[0].set_ylabel("y_pred")
ax[0].set_title("Test Set -Predicted vs real")

# Get a histogram of the residuals y - y_pred.  

ax[1].hist(y_test2 - y_pred2)
ax[1].set_xlabel("Test y-y_pred")
ax[1].set_title("Test Set Residual histogram")

ax[2].plot(y_pred,y_test - y_pred,"o")
ax[2].set_xlabel("predited")
ax[2].set_ylabel("residuals")
ax[2].set_title("Residuals by Predicted")
ax[2].plot(y_pred2,np.zeros(len(y_pred2)),linestyle='dashed')

# %% [markdown]
# #### Error metrics

# %%
print(mse(y_test2,y_pred2))
print(mae(y_test2,y_pred2))
# Out:
# 45060596291.60449
# 120599.43355729

# %% [markdown]
# #### Features Importance

# %% [markdown]
# Using the t score to measure the importance of the attributes, we can observe that
# quantile_zip, grade, age of the building and waterfront are the most important features.

# %% [markdown]
# ## Trial 3 : Linear regression with yr_renovated

# %%
#Transform yr_renovated: to determine if a property's value is influenced by the time lapsed since
#its renovation.

# %%
df
# Out:
#       bedrooms bathrooms  sqft_living  sqft_lot floors waterfront view  \
# 0            3    1.0000      -1.1094   -0.5178 1.0000          0    0
# 1            3    2.2500       0.6943   -0.1155 2.0000          0    0
# 2            2    1.0000      -2.1317    0.5628 1.0000          0    0
# 3            4    3.0000       0.0515   -0.7185 1.0000          0    0
# 4            3    2.0000      -0.2940    0.1280 1.0000          0    0
# ...        ...       ...          ...       ...    ...        ...  ...
# 21591        3    2.5000      -0.5092   -2.1322 3.0000          0    0
# 21592        4    2.5000       0.4362   -0.4751 2.0000          0    0
# 21593        2    0.7500      -1.4285   -1.8373 2.0000          0    0
# 21594        3    2.5000      -0.4061   -1.5155 2.0000          0    0
# 21595        2    0.7500      -1.4285   -2.2208 2.0000          0    0
#
#       condition grade basement age_build yr_renovated  sqft_living15  \
# 0             3     7        0        60            0        -1.0379
# 1             3     7        1        64         1991        -0.2471
# 2             3     6        0        82            0         1.0641
# 3             5     7        1        50            0        -0.9856
# 4             3     8        0        28            0        -0.0628
# ...         ...   ...      ...       ...          ...            ...
# 21591         3     8        0         6            0        -0.5731
# 21592         3     8        0         1            0        -0.0125
# 21593         3     7        0         6            0        -2.0431
# 21594         3     8        0        11            0        -0.8625
# 21595         3     7        0         7            0        -2.0431
#
#        sqft_lot15   price quantile_zip
# 0         -0.5181  221900            1
# 1          0.0075  538000            2
# 2          0.1541  180000            2
# 3         -0.7447  604000            3
# 4         -0.0404  510000            4
# ...           ...     ...          ...
# 21591     -1.8316  360000            3
# 21592     -0.1664  400000            2
# 21593     -1.6441  402101            3
# 21594     -2.0680  400000            3
# 21595     -1.9548  325000            3
#
# [21596 rows x 16 columns]

# %%
df['age_reno'] = list(map(lambda x: 2015-x if x !=0 else x, df['yr_renovated']))

# %%
df
# Out:
#       bedrooms bathrooms  sqft_living  sqft_lot floors waterfront view  \
# 0            3    1.0000      -1.1094   -0.5178 1.0000          0    0
# 1            3    2.2500       0.6943   -0.1155 2.0000          0    0
# 2            2    1.0000      -2.1317    0.5628 1.0000          0    0
# 3            4    3.0000       0.0515   -0.7185 1.0000          0    0
# 4            3    2.0000      -0.2940    0.1280 1.0000          0    0
# ...        ...       ...          ...       ...    ...        ...  ...
# 21591        3    2.5000      -0.5092   -2.1322 3.0000          0    0
# 21592        4    2.5000       0.4362   -0.4751 2.0000          0    0
# 21593        2    0.7500      -1.4285   -1.8373 2.0000          0    0
# 21594        3    2.5000      -0.4061   -1.5155 2.0000          0    0
# 21595        2    0.7500      -1.4285   -2.2208 2.0000          0    0
#
#       condition grade basement age_build yr_renovated  sqft_living15  \
# 0             3     7        0        60            0        -1.0379
# 1             3     7        1        64         1991        -0.2471
# 2             3     6        0        82            0         1.0641
# 3             5     7        1        50            0        -0.9856
# 4             3     8        0        28            0        -0.0628
# ...         ...   ...      ...       ...          ...            ...
# 21591         3     8        0         6            0        -0.5731
# 21592         3     8        0         1            0        -0.0125
# 21593         3     7        0         6            0        -2.0431
# 21594         3     8        0        11            0        -0.8625
# 21595         3     7        0         7            0        -2.0431
#
#        sqft_lot15   price quantile_zip  age_reno
# 0         -0.5181  221900            1         0
# 1          0.0075  538000            2        24
# 2          0.1541  180000            2         0
# 3         -0.7447  604000            3         0
# 4         -0.0404  510000            4         0
# ...           ...     ...          ...       ...
# 21591     -1.8316  360000            3         0
# 21592     -0.1664  400000            2         0
# 21593     -1.6441  402101            3         0
# 21594     -2.0680  400000            3         0
# 21595     -1.9548  325000            3         0
#
# [21596 rows x 17 columns]

# %%
df.drop(['yr_renovated'], axis=1, inplace=True)

# %%
df
# Out:
#       bedrooms bathrooms  sqft_living  sqft_lot floors waterfront view  \
# 0            3    1.0000      -1.1094   -0.5178 1.0000          0    0
# 1            3    2.2500       0.6943   -0.1155 2.0000          0    0
# 2            2    1.0000      -2.1317    0.5628 1.0000          0    0
# 3            4    3.0000       0.0515   -0.7185 1.0000          0    0
# 4            3    2.0000      -0.2940    0.1280 1.0000          0    0
# ...        ...       ...          ...       ...    ...        ...  ...
# 21591        3    2.5000      -0.5092   -2.1322 3.0000          0    0
# 21592        4    2.5000       0.4362   -0.4751 2.0000          0    0
# 21593        2    0.7500      -1.4285   -1.8373 2.0000          0    0
# 21594        3    2.5000      -0.4061   -1.5155 2.0000          0    0
# 21595        2    0.7500      -1.4285   -2.2208 2.0000          0    0
#
#       condition grade basement age_build  sqft_living15  sqft_lot15   price  \
# 0             3     7        0        60        -1.0379     -0.5181  221900
# 1             3     7        1        64        -0.2471      0.0075  538000
# 2             3     6        0        82         1.0641      0.1541  180000
# 3             5     7        1        50        -0.9856     -0.7447  604000
# 4             3     8        0        28        -0.0628     -0.0404  510000
# ...         ...   ...      ...       ...            ...         ...     ...
# 21591         3     8        0         6        -0.5731     -1.8316  360000
# 21592         3     8        0         1        -0.0125     -0.1664  400000
# 21593         3     7        0         6        -2.0431     -1.6441  402101
# 21594         3     8        0        11        -0.8625     -2.0680  400000
# 21595         3     7        0         7        -2.0431     -1.9548  325000
#
#       quantile_zip  age_reno
# 0                1         0
# 1                2        24
# 2                2         0
# 3                3         0
# 4                4         0
# ...            ...       ...
# 21591            3         0
# 21592            2         0
# 21593            3         0
# 21594            3         0
# 21595            3         0
#
# [21596 rows x 16 columns]

# %% [markdown]
# ### Xy Split

# %%
X4=df.drop('price', axis=1)
X4
y4=df.price
y4
# Out:
# 0        221900
# 1        538000
# 2        180000
# 3        604000
# 4        510000
#           ...
# 21591    360000
# 21592    400000
# 21593    402101
# 21594    400000
# 21595    325000
# Name: price, Length: 21596, dtype: int64

# %%
X4
# Out:
#       bedrooms bathrooms  sqft_living  sqft_lot floors waterfront view  \
# 0            3    1.0000      -1.1094   -0.5178 1.0000          0    0
# 1            3    2.2500       0.6943   -0.1155 2.0000          0    0
# 2            2    1.0000      -2.1317    0.5628 1.0000          0    0
# 3            4    3.0000       0.0515   -0.7185 1.0000          0    0
# 4            3    2.0000      -0.2940    0.1280 1.0000          0    0
# ...        ...       ...          ...       ...    ...        ...  ...
# 21591        3    2.5000      -0.5092   -2.1322 3.0000          0    0
# 21592        4    2.5000       0.4362   -0.4751 2.0000          0    0
# 21593        2    0.7500      -1.4285   -1.8373 2.0000          0    0
# 21594        3    2.5000      -0.4061   -1.5155 2.0000          0    0
# 21595        2    0.7500      -1.4285   -2.2208 2.0000          0    0
#
#       condition grade basement age_build  sqft_living15  sqft_lot15  \
# 0             3     7        0        60        -1.0379     -0.5181
# 1             3     7        1        64        -0.2471      0.0075
# 2             3     6        0        82         1.0641      0.1541
# 3             5     7        1        50        -0.9856     -0.7447
# 4             3     8        0        28        -0.0628     -0.0404
# ...         ...   ...      ...       ...            ...         ...
# 21591         3     8        0         6        -0.5731     -1.8316
# 21592         3     8        0         1        -0.0125     -0.1664
# 21593         3     7        0         6        -2.0431     -1.6441
# 21594         3     8        0        11        -0.8625     -2.0680
# 21595         3     7        0         7        -2.0431     -1.9548
#
#       quantile_zip  age_reno
# 0                1         0
# 1                2        24
# 2                2         0
# 3                3         0
# 4                4         0
# ...            ...       ...
# 21591            3         0
# 21592            2         0
# 21593            3         0
# 21594            3         0
# 21595            3         0
#
# [21596 rows x 15 columns]

# %% [markdown]
# ### Data Splitting

# %%
X_train4, X_test4, y_train4, y_test4 = train_test_split(X4, y4, test_size=.30,random_state=123)

# %% [markdown]
# ### Standardize

# %%
std_scaler4 = StandardScaler().fit(X_train4) 

X_train_scaled4 = std_scaler4.transform(X_train4)

X_test_scaled4 = std_scaler4.transform(X_test4)

# %% [markdown]
# ### Regression

# %%
X_train_const_scaled4 = sm.add_constant(X_train_scaled4) # adding a constant

model4 = sm.OLS(y_train4, X_train_const_scaled4).fit()
predictions_train4 = model4.predict(X_train_const_scaled4) 

X_test_const_scaled4 = sm.add_constant(X_test_scaled4) # adding a constant
predictions_test4 = model4.predict(X_test_const_scaled4) 
print_model4 = model4.summary()
print(print_model4)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.701
# Model:                            OLS   Adj. R-squared:                  0.701
# Method:                 Least Squares   F-statistic:                     2362.
# Date:                Fri, 11 Feb 2022   Prob (F-statistic):               0.00
# Time:                        12:05:46   Log-Likelihood:            -2.0594e+05
# No. Observations:               15117   AIC:                         4.119e+05
# Df Residuals:                   15101   BIC:                         4.120e+05
# Df Model:                          15
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       5.391e+05   1624.104    331.935      0.000    5.36e+05    5.42e+05
# x1         -1.056e+04   2210.799     -4.775      0.000   -1.49e+04   -6222.369
# x2          6.032e+04   2956.769     20.400      0.000    5.45e+04    6.61e+04
# x3          6.875e+04   3924.995     17.516      0.000    6.11e+04    7.64e+04
# x4          1.008e+04   4447.157      2.266      0.023    1360.978    1.88e+04
# x5         -3854.8436   2473.078     -1.559      0.119   -8702.377     992.689
# x6          6.122e+04   1782.726     34.340      0.000    5.77e+04    6.47e+04
# x7          4.429e+04   1889.319     23.441      0.000    4.06e+04     4.8e+04
# x8          1.022e+04   1780.996      5.737      0.000    6726.100    1.37e+04
# x9          1.425e+05   2887.247     49.343      0.000    1.37e+05    1.48e+05
# x10        -5701.8991   2005.351     -2.843      0.004   -9632.629   -1771.169
# x11          8.59e+04   2309.946     37.185      0.000    8.14e+04    9.04e+04
# x12         -799.3844   2702.386     -0.296      0.767   -6096.388    4497.620
# x13        -1.103e+04   4354.971     -2.532      0.011   -1.96e+04   -2492.605
# x14         1.134e+05   1847.169     61.404      0.000     1.1e+05    1.17e+05
# x15        -4967.2191   1695.822     -2.929      0.003   -8291.236   -1643.202
# ==============================================================================
# Omnibus:                    14938.558   Durbin-Watson:                   1.995
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          2275233.368
# Skew:                           4.460   Prob(JB):                         0.00
# Kurtosis:                      62.436   Cond. No.                         7.80
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# #### Model validation

# %%
#using sklearn
model4=LinearRegression()    # model
model4.fit(X_train_scaled4, y_train4)   # model trail
# Out:
# LinearRegression()

# %%
R2_test4 = model4.score(X_test_scaled4,y_test4) # measure R2
R2_test4
# Out:
# 0.674925129235102

# %%
y_pred4= model4.predict(X_test_scaled4)
y_pred4
# Out:
# array([413755.10528638, 302298.29098792, 479366.45690042, ...,
#        172596.22108249, 230310.79277598, 710518.8749579 ])

# %% [markdown]
# #### Error metrics

# %%
print(mse(y_test4,y_pred4))
print(mae(y_test4,y_pred4))
# Out:
# 45148449368.256676
# 120753.02519005562

# %% [markdown]
# The time since the renovation doesn'tseem to make any great difference on the price predictions.

# %% [markdown]
# ## Trial 4:

# %%
df5 = pd.read_excel('Data/Data_MidTerm_Project_Real_State_Regression.xls')

# %%
df5
# Out:
#                id       date  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0      7129300520 2014-10-13         3     1.0000         1180      5650
# 1      6414100192 2014-12-09         3     2.2500         2570      7242
# 2      5631500400 2015-02-25         2     1.0000          770     10000
# 3      2487200875 2014-12-09         4     3.0000         1960      5000
# 4      1954400510 2015-02-18         3     2.0000         1680      8080
# ...           ...        ...       ...        ...          ...       ...
# 21592   263000018 2014-05-21         3     2.5000         1530      1131
# 21593  6600060120 2015-02-23         4     2.5000         2310      5813
# 21594  1523300141 2014-06-23         2     0.7500         1020      1350
# 21595   291310100 2015-01-16         3     2.5000         1600      2388
# 21596  1523300157 2014-10-15         2     0.7500         1020      1076
#
#        floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0      1.0000           0     0          3      7        1180              0
# 1      2.0000           0     0          3      7        2170            400
# 2      1.0000           0     0          3      6         770              0
# 3      1.0000           0     0          5      7        1050            910
# 4      1.0000           0     0          3      8        1680              0
# ...       ...         ...   ...        ...    ...         ...            ...
# 21592  3.0000           0     0          3      8        1530              0
# 21593  2.0000           0     0          3      8        2310              0
# 21594  2.0000           0     0          3      7        1020              0
# 21595  2.0000           0     0          3      8        1600              0
# 21596  2.0000           0     0          3      7        1020              0
#
#        yr_built  yr_renovated  zipcode     lat      long  sqft_living15  \
# 0          1955             0    98178 47.5112 -122.2570           1340
# 1          1951          1991    98125 47.7210 -122.3190           1690
# 2          1933             0    98028 47.7379 -122.2330           2720
# 3          1965             0    98136 47.5208 -122.3930           1360
# 4          1987             0    98074 47.6168 -122.0450           1800
# ...         ...           ...      ...     ...       ...            ...
# 21592      2009             0    98103 47.6993 -122.3460           1530
# 21593      2014             0    98146 47.5107 -122.3620           1830
# 21594      2009             0    98144 47.5944 -122.2990           1020
# 21595      2004             0    98027 47.5345 -122.0690           1410
# 21596      2008             0    98144 47.5941 -122.2990           1020
#
#        sqft_lot15   price
# 0            5650  221900
# 1            7639  538000
# 2            8062  180000
# 3            5000  604000
# 4            7503  510000
# ...           ...     ...
# 21592        1509  360000
# 21593        7200  400000
# 21594        2007  402101
# 21595        1287  400000
# 21596        1357  325000
#
# [21597 rows x 21 columns]

# %% [markdown]
# ### Data Cleaning

# %% [markdown]
# #### Drop the columns with less impact and mistake row

# %%
df5 = df5.drop(['id','lat', 'long', 'date', 'bedrooms', 'sqft_lot', 'floors', 'condition', 'sqft_above', 'sqft_basement', 'yr_renovated', 'sqft_living15', 'sqft_lot15'], axis=1)
df5
# Out:
#        bathrooms  sqft_living  waterfront  view  grade  yr_built  zipcode  \
# 0         1.0000         1180           0     0      7      1955    98178
# 1         2.2500         2570           0     0      7      1951    98125
# 2         1.0000          770           0     0      6      1933    98028
# 3         3.0000         1960           0     0      7      1965    98136
# 4         2.0000         1680           0     0      8      1987    98074
# ...          ...          ...         ...   ...    ...       ...      ...
# 21592     2.5000         1530           0     0      8      2009    98103
# 21593     2.5000         2310           0     0      8      2014    98146
# 21594     0.7500         1020           0     0      7      2009    98144
# 21595     2.5000         1600           0     0      8      2004    98027
# 21596     0.7500         1020           0     0      7      2008    98144
#
#         price
# 0      221900
# 1      538000
# 2      180000
# 3      604000
# 4      510000
# ...       ...
# 21592  360000
# 21593  400000
# 21594  402101
# 21595  400000
# 21596  325000
#
# [21597 rows x 8 columns]

# %%
df5 = df5.drop(15856).reset_index(drop=True)

# %%
df5
# Out:
#        bathrooms  sqft_living  waterfront  view  grade  yr_built  zipcode  \
# 0         1.0000         1180           0     0      7      1955    98178
# 1         2.2500         2570           0     0      7      1951    98125
# 2         1.0000          770           0     0      6      1933    98028
# 3         3.0000         1960           0     0      7      1965    98136
# 4         2.0000         1680           0     0      8      1987    98074
# ...          ...          ...         ...   ...    ...       ...      ...
# 21591     2.5000         1530           0     0      8      2009    98103
# 21592     2.5000         2310           0     0      8      2014    98146
# 21593     0.7500         1020           0     0      7      2009    98144
# 21594     2.5000         1600           0     0      8      2004    98027
# 21595     0.7500         1020           0     0      7      2008    98144
#
#         price
# 0      221900
# 1      538000
# 2      180000
# 3      604000
# 4      510000
# ...       ...
# 21591  360000
# 21592  400000
# 21593  402101
# 21594  400000
# 21595  325000
#
# [21596 rows x 8 columns]

# %% [markdown]
# #### Transform yr_buitl and yr_renovated

# %%
df5['yr_built']= list(map(lambda x: 2015-x, df5['yr_built']))

# %%
df5['yr_built']
# Out:
# 0        60
# 1        64
# 2        82
# 3        50
# 4        28
#          ..
# 21591     6
# 21592     1
# 21593     6
# 21594    11
# 21595     7
# Name: yr_built, Length: 21596, dtype: int64

# %%
df5.rename(columns = {'yr_built' : 'age_build'}, inplace=True)

# %%
df5
# Out:
#        bathrooms  sqft_living  waterfront  view  grade  age_build  zipcode  \
# 0         1.0000         1180           0     0      7         60    98178
# 1         2.2500         2570           0     0      7         64    98125
# 2         1.0000          770           0     0      6         82    98028
# 3         3.0000         1960           0     0      7         50    98136
# 4         2.0000         1680           0     0      8         28    98074
# ...          ...          ...         ...   ...    ...        ...      ...
# 21591     2.5000         1530           0     0      8          6    98103
# 21592     2.5000         2310           0     0      8          1    98146
# 21593     0.7500         1020           0     0      7          6    98144
# 21594     2.5000         1600           0     0      8         11    98027
# 21595     0.7500         1020           0     0      7          7    98144
#
#         price
# 0      221900
# 1      538000
# 2      180000
# 3      604000
# 4      510000
# ...       ...
# 21591  360000
# 21592  400000
# 21593  402101
# 21594  400000
# 21595  325000
#
# [21596 rows x 8 columns]

# %% [markdown]
# #### Round bathrooms

# %%
#Rounding down the number of bathrooms, expect for those under 1
# Replacing all values over 5 with 5

# %%
df5['bathrooms'] = round(df5['bathrooms'])
df5['bathrooms'] = np.where(df5['bathrooms'] == 0, 1, df5['bathrooms'])
df5['bathrooms'] = np.where(df5['bathrooms'] > 5, 5, df5['bathrooms'])

# %% [markdown]
# ### Data transformation

# %% [markdown]
# #### Transformation of the target variable

# %%
df5.price.hist()
# Out:
# <AxesSubplot:>

# %%
# Use the log function of numpy to normalize price, since it is a log normal distribution skewed to the left.

# %%
df5.price = np.log(df.price.values)

# %%
df5.price.hist()
# Out:
# <AxesSubplot:>

# %%
sns.histplot(np.log(df5.price.values))
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
df5
# Out:
#        bathrooms  sqft_living  waterfront  view  grade  age_build  zipcode  \
# 0         1.0000         1180           0     0      7         60    98178
# 1         2.0000         2570           0     0      7         64    98125
# 2         1.0000          770           0     0      6         82    98028
# 3         3.0000         1960           0     0      7         50    98136
# 4         2.0000         1680           0     0      8         28    98074
# ...          ...          ...         ...   ...    ...        ...      ...
# 21591     2.0000         1530           0     0      8          6    98103
# 21592     2.0000         2310           0     0      8          1    98146
# 21593     1.0000         1020           0     0      7          6    98144
# 21594     2.0000         1600           0     0      8         11    98027
# 21595     1.0000         1020           0     0      7          7    98144
#
#         price
# 0     12.3100
# 1     13.1956
# 2     12.1007
# 3     13.3113
# 4     13.1422
# ...       ...
# 21591 12.7939
# 21592 12.8992
# 21593 12.9045
# 21594 12.8992
# 21595 12.6916
#
# [21596 rows x 8 columns]

# %% [markdown]
# #### Zipcode new grouping

# %%
price_zip_mean = df5.groupby(['zipcode'])['price'].mean()
price_zip_mean.sort_values(ascending=False)
# Out:
# zipcode
# 98039   14.4704
# 98004   14.0087
# 98040   13.9030
# 98112   13.7798
# 98109   13.5857
#           ...
# 98023   12.5124
# 98001   12.4931
# 98032   12.3982
# 98168   12.3445
# 98002   12.3377
# Name: price, Length: 70, dtype: float64

# %%
price_zip = df5.groupby(['zipcode'])['price'].mean()
pz = price_zip.sort_values(ascending=False).reset_index()
pz
# Out:
#     zipcode   price
# 0     98039 14.4704
# 1     98004 14.0087
# 2     98040 13.9030
# 3     98112 13.7798
# 4     98109 13.5857
# ..      ...     ...
# 65    98023 12.5124
# 66    98001 12.4931
# 67    98032 12.3982
# 68    98168 12.3445
# 69    98002 12.3377
#
# [70 rows x 2 columns]

# %%
df5
# Out:
#        bathrooms  sqft_living  waterfront  view  grade  age_build  zipcode  \
# 0         1.0000         1180           0     0      7         60    98178
# 1         2.0000         2570           0     0      7         64    98125
# 2         1.0000          770           0     0      6         82    98028
# 3         3.0000         1960           0     0      7         50    98136
# 4         2.0000         1680           0     0      8         28    98074
# ...          ...          ...         ...   ...    ...        ...      ...
# 21591     2.0000         1530           0     0      8          6    98103
# 21592     2.0000         2310           0     0      8          1    98146
# 21593     1.0000         1020           0     0      7          6    98144
# 21594     2.0000         1600           0     0      8         11    98027
# 21595     1.0000         1020           0     0      7          7    98144
#
#         price
# 0     12.3100
# 1     13.1956
# 2     12.1007
# 3     13.3113
# 4     13.1422
# ...       ...
# 21591 12.7939
# 21592 12.8992
# 21593 12.9045
# 21594 12.8992
# 21595 12.6916
#
# [21596 rows x 8 columns]

# %%
#To increase the accuracy we devide into even smaller groups, 1 group per percetile of the average of price

P1 = np.percentile(pz['price'], 10)
P2 = np.percentile(pz['price'], 20)
P3 = np.percentile(pz['price'], 30)
P4 = np.percentile(pz['price'], 40)
P5 = np.percentile(pz['price'], 50)
P6 = np.percentile(pz['price'], 60)
P7 = np.percentile(pz['price'], 70)
P8 = np.percentile(pz['price'], 80)
P9 = np.percentile(pz['price'], 90)

# %%
pz['percentile_zip'] = "1"
pz['percentile_zip'] = np.where(pz['price'] >= P1, "2", pz['percentile_zip'])
pz['percentile_zip'] = np.where(pz['price'] >= P2, "3", pz['percentile_zip'])
pz['percentile_zip'] = np.where(pz['price'] >= P3, "4", pz['percentile_zip'])
pz['percentile_zip'] = np.where(pz['price'] >= P4, "5", pz['percentile_zip'])
pz['percentile_zip'] = np.where(pz['price'] >= P5, "6", pz['percentile_zip'])
pz['percentile_zip'] = np.where(pz['price'] >= P6, "7", pz['percentile_zip'])
pz['percentile_zip'] = np.where(pz['price'] >= P7, "8", pz['percentile_zip'])
pz['percentile_zip'] = np.where(pz['price'] >= P8, "9", pz['percentile_zip'])
pz['percentile_zip'] = np.where(pz['price'] >= P9, "10", pz['percentile_zip'])

# %%
pz
# Out:
#     zipcode   price percentile_zip
# 0     98039 14.4704             10
# 1     98004 14.0087             10
# 2     98040 13.9030             10
# 3     98112 13.7798             10
# 4     98109 13.5857             10
# ..      ...     ...            ...
# 65    98023 12.5124              1
# 66    98001 12.4931              1
# 67    98032 12.3982              1
# 68    98168 12.3445              1
# 69    98002 12.3377              1
#
# [70 rows x 3 columns]

# %%
pz.groupby('percentile_zip').count()
# Out:
#                 zipcode  price
# percentile_zip
# 1                     7      7
# 10                    7      7
# 2                     7      7
# 3                     7      7
# 4                     7      7
# 5                     7      7
# 6                     7      7
# 7                     7      7
# 8                     7      7
# 9                     7      7

# %%
df5 = pd.merge(df5, pz[['zipcode', 'percentile_zip']], on='zipcode', how='inner').sample(frac=1).reset_index(drop=True)

# %%
df5
# Out:
#        bathrooms  sqft_living  waterfront  view  grade  age_build  zipcode  \
# 0         4.0000         3720           0     2      9          9    98116
# 1         3.0000         2980           0     0      9         42    98005
# 2         2.0000         2630           0     0      9         48    98006
# 3         4.0000         3420           0     0      9         11    98010
# 4         1.0000         1100           0     0      7         46    98042
# ...          ...          ...         ...   ...    ...        ...      ...
# 21591     2.0000         2520           0     0      7         36    98023
# 21592     3.0000         1860           0     0      9         98    98103
# 21593     2.0000         1330           0     0      7         32    98052
# 21594     3.0000         3880           0     0      7         11    98056
# 21595     2.0000         1300           0     0      8          7    98103
#
#         price percentile_zip
# 0     13.8643              7
# 1     13.7632              9
# 2     13.6559             10
# 3     13.3924              4
# 4     12.0347              2
# ...       ...            ...
# 21591 12.5136              1
# 21592 13.7820              7
# 21593 13.0711              8
# 21594 13.0058              4
# 21595 13.2393              7
#
# [21596 rows x 9 columns]

# %%
df5 = df5.drop(columns=['zipcode'], axis=1).reset_index(drop=True)

# %%
df5.to_excel("df5_final_trial_Alejandra.xlsx")

# %% [markdown]
# ### Xy Split

# %%
X5=df5.drop('price', axis=1)
X5
# Out:
#        bathrooms  sqft_living  waterfront  view  grade  age_build  \
# 0         4.0000         3720           0     2      9          9
# 1         3.0000         2980           0     0      9         42
# 2         2.0000         2630           0     0      9         48
# 3         4.0000         3420           0     0      9         11
# 4         1.0000         1100           0     0      7         46
# ...          ...          ...         ...   ...    ...        ...
# 21591     2.0000         2520           0     0      7         36
# 21592     3.0000         1860           0     0      9         98
# 21593     2.0000         1330           0     0      7         32
# 21594     3.0000         3880           0     0      7         11
# 21595     2.0000         1300           0     0      8          7
#
#       percentile_zip
# 0                  7
# 1                  9
# 2                 10
# 3                  4
# 4                  2
# ...              ...
# 21591              1
# 21592              7
# 21593              8
# 21594              4
# 21595              7
#
# [21596 rows x 7 columns]

# %%
y5=df5.price
y5
# Out:
# 0       13.8643
# 1       13.7632
# 2       13.6559
# 3       13.3924
# 4       12.0347
#           ...
# 21591   12.5136
# 21592   13.7820
# 21593   13.0711
# 21594   13.0058
# 21595   13.2393
# Name: price, Length: 21596, dtype: float64

# %% [markdown]
# ### Data Splitting

# %%
X_train5, X_test5, y_train5, y_test5 = train_test_split(X5, y5, test_size=.30,random_state=123)

# %% [markdown]
# ### Standardize

# %%
std_scaler5 = StandardScaler().fit(X_train5) 

X_train_scaled5 = std_scaler5.transform(X_train5)

# %%
X_test_scaled5 = std_scaler5.transform(X_test5)

# %%
print(X_train_scaled5)
print("--------")
print(X_test_scaled5)
# Out:
# [[-0.07772172 -0.06037367 -0.08443092 ... -0.55721079 -0.13659869
#    1.28576173]
#  [-0.07772172 -0.25699372 -0.08443092 ...  1.15642068 -0.23852684
#    0.91877925]
#  [-0.07772172  0.48579314 -0.08443092 ...  2.01323642 -0.23852684
#    1.28576173]
#  ...
#  [-1.41134179 -1.41486735 -0.08443092 ... -1.41402653  1.01858699
#   -0.91613315]
#  [-0.07772172 -0.74854384 -0.08443092 ... -0.55721079 -0.54431128
#   -0.91613315]
#  [-0.07772172  0.39840645 -0.08443092 ...  1.15642068  0.37304205
#    0.91877925]]
# --------
# [[ 2.58951841  1.6545901  -0.08443092 ...  1.15642068 -1.18985622
#    0.55179677]
#  [-0.07772172  1.07565328 -0.08443092 ...  1.15642068 -1.15588017
#    0.91877925]
#  [-1.41134179 -0.96701057 -0.08443092 ... -1.41402653  0.4070181
#   -0.91613315]
#  ...
#  [-0.07772172 -0.65023382 -0.08443092 ... -0.55721079  1.05256304
#   -0.91613315]
#  [-0.07772172  1.67643677 -0.08443092 ...  2.01323642  1.39232354
#   -0.54915067]
#  [-0.07772172 -0.73762051 -0.08443092 ... -1.41402653  2.27570082
#    0.55179677]]

# %% [markdown]
# ### Regression

# %%
X_train_const_scaled5 = sm.add_constant(X_train_scaled5) 

model5 = sm.OLS(y_train5, X_train_const_scaled5).fit()
predictions_train5 = model5.predict(X_train_const_scaled5) 

X_test_const_scaled5 = sm.add_constant(X_test_scaled5) 
predictions_test5 = model5.predict(X_test_const_scaled5) 
print_model5 = model5.summary()
print(print_model5)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.833
# Model:                            OLS   Adj. R-squared:                  0.833
# Method:                 Least Squares   F-statistic:                 1.080e+04
# Date:                Fri, 11 Feb 2022   Prob (F-statistic):               0.00
# Time:                        12:06:08   Log-Likelihood:                 1826.6
# No. Observations:               15117   AIC:                            -3637.
# Df Residuals:                   15109   BIC:                            -3576.
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         13.0457      0.002   7478.206      0.000      13.042      13.049
# x1             0.0331      0.003     13.147      0.000       0.028       0.038
# x2             0.1721      0.003     55.558      0.000       0.166       0.178
# x3             0.0365      0.002     19.245      0.000       0.033       0.040
# x4             0.0476      0.002     23.788      0.000       0.044       0.052
# x5             0.1407      0.003     45.993      0.000       0.135       0.147
# x6             0.0744      0.002     35.360      0.000       0.070       0.079
# x7             0.2604      0.002    133.591      0.000       0.257       0.264
# ==============================================================================
# Omnibus:                      606.274   Durbin-Watson:                   1.975
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1525.299
# Skew:                          -0.207   Prob(JB):                         0.00
# Kurtosis:                       4.500   Cond. No.                         3.92
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# #### Model Validation

# %%
model5=LinearRegression()   
model5.fit(X_train_scaled5, y_train5)
# Out:
# LinearRegression()

# %%
model5.coef_
# Out:
# array([0.03307462, 0.17212387, 0.03651926, 0.0476115 , 0.1406903 ,
#        0.07441233, 0.26044769])

# %%
model5.intercept_
# Out:
# 13.045707383636103

# %%
R2_test = model5.score(X_test_scaled5,y_test5) # measure R2
R2_test
# Out:
# 0.830179052739542

# %%
# Making prediction
y_pred5 = model5.predict(X_test_scaled5)
y_pred5
# Out:
# array([13.74187457, 13.52673894, 12.40780199, ..., 12.67501797,
#        13.68336942, 13.01276646])

# %%
y_test5
# Out:
# 14863   14.0779
# 2277    13.5318
# 21578   12.0254
# 18669   12.9598
# 21453   13.1654
#           ...
# 12811   13.5285
# 12288   13.7642
# 6556    13.1022
# 16310   13.8353
# 1050    13.1956
# Name: price, Length: 6479, dtype: float64

# %%
result=pd.DataFrame({"y_test":y_test5,"y_pred":y_pred5})

# %%
# Scatter plot y_pred vs y

fig, ax = plt.subplots(1,3,figsize=(14,4))
ax[0].plot(y_pred5, y_test5, 'o')
ax[0].set_xlabel("y_test")
ax[0].set_ylabel("y_pred")
ax[0].set_title("Test Set -Predicted vs real")

# histogram of the residuals: y - y_pred

ax[1].hist(y_test5 - y_pred5)
ax[1].set_xlabel("Test y-y_pred")
ax[1].set_title("Test Set Residual histogram")

ax[2].plot(y_pred5,y_test5 - y_pred5,"o")
ax[2].set_xlabel("predited")
ax[2].set_ylabel("residuals")
ax[2].set_title("Residuals by Predicted")
ax[2].plot(y_pred5,np.zeros(len(y_pred5)),linestyle='dashed')

# %%
# It resembles a normal distribution.

# %%
sns.regplot(x='y_pred',y='y_test', data=result, scatter_kws={"color": "olive"}, line_kws={"color": "black"})
# Out:
# <AxesSubplot:xlabel='y_pred', ylabel='y_test'>

# %%
#Data points align in a straight line.

# %% [markdown]
# #### Error Metrics

# %%
print(mse(y_test5,y_pred5))
print(mae(y_test5,y_pred5))
# Out:
# 0.0475313017215632
# 0.16341892835487437

# %%
### Comments: numerical variables where not transformed, most important features were location (zip) and size (sqft_living).
