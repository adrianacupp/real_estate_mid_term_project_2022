# %% [markdown]
# ## Exploratory Data Analysis: houses over 650K

# %% [markdown]
# ### Importing the libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib.colors import ListedColormap

import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import minmax_scale
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PowerTransformer
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import (StandardScaler, MinMaxScaler)
from sklearn.preprocessing import QuantileTransformer

import statsmodels.api as sm
from scipy.stats import boxcox
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import mean_absolute_error as mae
pd.options.display.max_rows = 50
pd.set_option('max_columns', None)

pd.set_option('display.float_format', lambda x: '%0.4f' % x)

# %% [markdown]
# ### Import dataset

# %%
df = pd.read_excel('Data/Data_MidTerm_Project_Real_State_Regression.xls')
df
# Out:
#                id       date  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0      7129300520 2014-10-13         3     1.0000         1180      5650
# 1      6414100192 2014-12-09         3     2.2500         2570      7242
# 2      5631500400 2015-02-25         2     1.0000          770     10000
# 3      2487200875 2014-12-09         4     3.0000         1960      5000
# 4      1954400510 2015-02-18         3     2.0000         1680      8080
# ...           ...        ...       ...        ...          ...       ...
# 21592   263000018 2014-05-21         3     2.5000         1530      1131
# 21593  6600060120 2015-02-23         4     2.5000         2310      5813
# 21594  1523300141 2014-06-23         2     0.7500         1020      1350
# 21595   291310100 2015-01-16         3     2.5000         1600      2388
# 21596  1523300157 2014-10-15         2     0.7500         1020      1076
#
#        floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0      1.0000           0     0          3      7        1180              0
# 1      2.0000           0     0          3      7        2170            400
# 2      1.0000           0     0          3      6         770              0
# 3      1.0000           0     0          5      7        1050            910
# 4      1.0000           0     0          3      8        1680              0
# ...       ...         ...   ...        ...    ...         ...            ...
# 21592  3.0000           0     0          3      8        1530              0
# 21593  2.0000           0     0          3      8        2310              0
# 21594  2.0000           0     0          3      7        1020              0
# 21595  2.0000           0     0          3      8        1600              0
# 21596  2.0000           0     0          3      7        1020              0
#
#        yr_built  yr_renovated  zipcode     lat      long  sqft_living15  \
# 0          1955             0    98178 47.5112 -122.2570           1340
# 1          1951          1991    98125 47.7210 -122.3190           1690
# 2          1933             0    98028 47.7379 -122.2330           2720
# 3          1965             0    98136 47.5208 -122.3930           1360
# 4          1987             0    98074 47.6168 -122.0450           1800
# ...         ...           ...      ...     ...       ...            ...
# 21592      2009             0    98103 47.6993 -122.3460           1530
# 21593      2014             0    98146 47.5107 -122.3620           1830
# 21594      2009             0    98144 47.5944 -122.2990           1020
# 21595      2004             0    98027 47.5345 -122.0690           1410
# 21596      2008             0    98144 47.5941 -122.2990           1020
#
#        sqft_lot15   price
# 0            5650  221900
# 1            7639  538000
# 2            8062  180000
# 3            5000  604000
# 4            7503  510000
# ...           ...     ...
# 21592        1509  360000
# 21593        7200  400000
# 21594        2007  402101
# 21595        1287  400000
# 21596        1357  325000
#
# [21597 rows x 21 columns]

# %%
df["price650"] = df["price"] >= 650000
df
# Out:
#                id       date  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0      7129300520 2014-10-13         3     1.0000         1180      5650
# 1      6414100192 2014-12-09         3     2.2500         2570      7242
# 2      5631500400 2015-02-25         2     1.0000          770     10000
# 3      2487200875 2014-12-09         4     3.0000         1960      5000
# 4      1954400510 2015-02-18         3     2.0000         1680      8080
# ...           ...        ...       ...        ...          ...       ...
# 21592   263000018 2014-05-21         3     2.5000         1530      1131
# 21593  6600060120 2015-02-23         4     2.5000         2310      5813
# 21594  1523300141 2014-06-23         2     0.7500         1020      1350
# 21595   291310100 2015-01-16         3     2.5000         1600      2388
# 21596  1523300157 2014-10-15         2     0.7500         1020      1076
#
#        floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0      1.0000           0     0          3      7        1180              0
# 1      2.0000           0     0          3      7        2170            400
# 2      1.0000           0     0          3      6         770              0
# 3      1.0000           0     0          5      7        1050            910
# 4      1.0000           0     0          3      8        1680              0
# ...       ...         ...   ...        ...    ...         ...            ...
# 21592  3.0000           0     0          3      8        1530              0
# 21593  2.0000           0     0          3      8        2310              0
# 21594  2.0000           0     0          3      7        1020              0
# 21595  2.0000           0     0          3      8        1600              0
# 21596  2.0000           0     0          3      7        1020              0
#
#        yr_built  yr_renovated  zipcode     lat      long  sqft_living15  \
# 0          1955             0    98178 47.5112 -122.2570           1340
# 1          1951          1991    98125 47.7210 -122.3190           1690
# 2          1933             0    98028 47.7379 -122.2330           2720
# 3          1965             0    98136 47.5208 -122.3930           1360
# 4          1987             0    98074 47.6168 -122.0450           1800
# ...         ...           ...      ...     ...       ...            ...
# 21592      2009             0    98103 47.6993 -122.3460           1530
# 21593      2014             0    98146 47.5107 -122.3620           1830
# 21594      2009             0    98144 47.5944 -122.2990           1020
# 21595      2004             0    98027 47.5345 -122.0690           1410
# 21596      2008             0    98144 47.5941 -122.2990           1020
#
#        sqft_lot15   price  price650
# 0            5650  221900     False
# 1            7639  538000     False
# 2            8062  180000     False
# 3            5000  604000     False
# 4            7503  510000     False
# ...           ...     ...       ...
# 21592        1509  360000     False
# 21593        7200  400000     False
# 21594        2007  402101     False
# 21595        1287  400000     False
# 21596        1357  325000     False
#
# [21597 rows x 22 columns]

# %%
df = df[df['price650']]

# %%
df
# Out:
#            date  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0    2015-02-23         3     2.0000       0.1067      5657  1.5000
# 1    2014-11-21         4     2.0000       0.2221      7051  2.0000
# 2    2014-10-22         3     2.0000       0.1494      5467  2.0000
# 3    2014-10-08         2     2.0000       0.1123      3313  2.0000
# 4    2015-03-11         5     3.0000       0.1842      5934  2.0000
# ...         ...       ...        ...          ...       ...     ...
# 5317 2015-02-02         6     4.0000       0.3929     13928  2.0000
# 5318 2014-05-20         4     2.0000       0.1320     12100  1.0000
# 5319 2014-10-13         2     2.0000       0.0941      8112  1.0000
# 5320 2014-06-24         4     4.0000       0.1818     31450  2.0000
# 5321 2014-06-24         4     2.0000       0.2103     13900  1.0000
#
#       waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0              0     2          4      8        1910            330
# 1              0     0          3     11        3700              0
# 2              0     2          3      9        2780              0
# 3              0     0          3      9        2310              0
# 4              0     0          3      9        3220              0
# ...          ...   ...        ...    ...         ...            ...
# 5317           0     3          3     10        4150           1710
# 5318           0     0          4      8        1760            800
# 5319           1     4          4      8        1040           1040
# 5320           0     0          3      9        3190              0
# 5321           0     0          3      8        1830           1720
#
#       age_build  yr_renovated     lat      long  sqft_living15  sqft_lot15  \
# 0            74             0 47.6621 -122.2700           2970        5657
# 1             9             0 47.5427 -121.9950           3580        6175
# 2            15             0 47.5791 -122.3780           2630        5000
# 3             9             0 47.6318 -122.3650           2700        5670
# 4             9             0 47.7076 -122.1010           3100        5934
# ...         ...           ...     ...       ...            ...         ...
# 5317          2             0 47.5382 -122.1140           5790       13928
# 5318         39             0 47.6310 -122.1080           2240       12100
# 5319         76          1984 47.7134 -122.2770           2030        8408
# 5320          5             0 47.5010 -121.9020           3000       72745
# 5321          5             0 47.5681 -122.1270           2770       12200
#
#         price quantile_zip  renov_yn
# 0     1270000           10         0
# 1      950000            3         0
# 2      775000            2         0
# 3     1250000            8         0
# 4      798000            2         0
# ...       ...          ...       ...
# 5317  1750000            9         0
# 5318   765000            2         0
# 5319  1190000            6         1
# 5320   790000            7         0
# 5321   859000            9         0
#
# [5322 rows x 21 columns]

# %%
df.waterfront.value_counts()
# Out:
# 0    5188
# 1     134
# Name: waterfront, dtype: int64

# %%
corr_650 = df.corr(method='spearman').abs()
corr_650
# Out:
#                   id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# id            1.0000    0.0120     0.0602       0.0767    0.1482  0.0242
# bedrooms      0.0120    1.0000     0.4297       0.4753    0.1427  0.1761
# bathrooms     0.0602    0.4297     1.0000       0.6991    0.1989  0.3960
# sqft_living   0.0767    0.4753     0.6991       1.0000    0.4468  0.3623
# sqft_lot      0.1482    0.1427     0.1989       0.4468    1.0000  0.0748
# floors        0.0242    0.1761     0.3960       0.3623    0.0748  1.0000
# waterfront    0.0066    0.0574     0.0375       0.0486    0.1153  0.0037
# view          0.0179    0.0265     0.0964       0.1360    0.1009  0.0923
# condition     0.0200    0.0406     0.2355       0.2231    0.0297  0.3286
# grade         0.0646    0.2196     0.5509       0.6959    0.3956  0.4369
# sqft_above    0.0734    0.3695     0.5926       0.8173    0.4339  0.6007
# sqft_basement 0.0114    0.1542     0.1523       0.1958    0.0560  0.3627
# yr_built      0.0188    0.1328     0.4537       0.4284    0.1679  0.4453
# yr_renovated  0.0054    0.0202     0.0522       0.0240    0.0497  0.0087
# zipcode       0.0014    0.1354     0.1390       0.2176    0.4365  0.0082
# lat           0.0284    0.0640     0.1019       0.1392    0.1613  0.0350
# long          0.0070    0.1515     0.2390       0.3639    0.4779  0.1962
# sqft_living15 0.0308    0.2452     0.3720       0.6177    0.5115  0.1983
# sqft_lot15    0.1438    0.1313     0.1962       0.4342    0.9306  0.0558
# price         0.0755    0.2267     0.4049       0.5331    0.2181  0.1608
# price650         NaN       NaN        NaN          NaN       NaN     NaN
#
#                waterfront   view  condition  grade  sqft_above  sqft_basement  \
# id                 0.0066 0.0179     0.0200 0.0646      0.0734         0.0114
# bedrooms           0.0574 0.0265     0.0406 0.2196      0.3695         0.1542
# bathrooms          0.0375 0.0964     0.2355 0.5509      0.5926         0.1523
# sqft_living        0.0486 0.1360     0.2231 0.6959      0.8173         0.1958
# sqft_lot           0.1153 0.1009     0.0297 0.3956      0.4339         0.0560
# floors             0.0037 0.0923     0.3286 0.4369      0.6007         0.3627
# waterfront         1.0000 0.3400     0.0070 0.0369      0.0131         0.0713
# view               0.3400 1.0000     0.0613 0.1053      0.0376         0.3138
# condition          0.0070 0.0613     1.0000 0.3130      0.3522         0.2360
# grade              0.0369 0.1053     0.3130 1.0000      0.7207         0.0829
# sqft_above         0.0131 0.0376     0.3522 0.7207      1.0000         0.3527
# sqft_basement      0.0713 0.3138     0.2360 0.0829      0.3527         1.0000
# yr_built           0.0415 0.1208     0.5187 0.5122      0.5615         0.2691
# yr_renovated       0.0932 0.1108     0.1163 0.0711      0.0762         0.1055
# zipcode            0.0646 0.1567     0.0647 0.2286      0.2737         0.1374
# lat                0.0923 0.1445     0.0028 0.1621      0.1104         0.0338
# long               0.0524 0.2109     0.2587 0.3636      0.5092         0.3154
# sqft_living15      0.0551 0.1623     0.1630 0.6139      0.5975         0.0330
# sqft_lot15         0.1249 0.1012     0.0324 0.4124      0.4291         0.0668
# price              0.1786 0.2872     0.0155 0.5138      0.4012         0.1927
# price650              NaN    NaN        NaN    NaN         NaN            NaN
#
#                yr_built  yr_renovated  zipcode    lat   long  sqft_living15  \
# id               0.0188        0.0054   0.0014 0.0284 0.0070         0.0308
# bedrooms         0.1328        0.0202   0.1354 0.0640 0.1515         0.2452
# bathrooms        0.4537        0.0522   0.1390 0.1019 0.2390         0.3720
# sqft_living      0.4284        0.0240   0.2176 0.1392 0.3639         0.6177
# sqft_lot         0.1679        0.0497   0.4365 0.1613 0.4779         0.5115
# floors           0.4453        0.0087   0.0082 0.0350 0.1962         0.1983
# waterfront       0.0415        0.0932   0.0646 0.0923 0.0524         0.0551
# view             0.1208        0.1108   0.1567 0.1445 0.2109         0.1623
# condition        0.5187        0.1163   0.0647 0.0028 0.2587         0.1630
# grade            0.5122        0.0711   0.2286 0.1621 0.3636         0.6139
# sqft_above       0.5615        0.0762   0.2737 0.1104 0.5092         0.5975
# sqft_basement    0.2691        0.1055   0.1374 0.0338 0.3154         0.0330
# yr_built         1.0000        0.2887   0.3316 0.0918 0.5275         0.3375
# yr_renovated     0.2887        1.0000   0.1270 0.0096 0.1852         0.1040
# zipcode          0.3316        0.1270   1.0000 0.2290 0.6259         0.3599
# lat              0.0918        0.0096   0.2290 1.0000 0.1985         0.1877
# long             0.5275        0.1852   0.6259 0.1985 1.0000         0.5241
# sqft_living15    0.3375        0.1040   0.3599 0.1877 0.5241         1.0000
# sqft_lot15       0.2029        0.0519   0.4660 0.1643 0.4877         0.5547
# price            0.0562        0.1147   0.1093 0.0535 0.0694         0.3927
# price650            NaN           NaN      NaN    NaN    NaN            NaN
#
#                sqft_lot15  price  price650
# id                 0.1438 0.0755       NaN
# bedrooms           0.1313 0.2267       NaN
# bathrooms          0.1962 0.4049       NaN
# sqft_living        0.4342 0.5331       NaN
# sqft_lot           0.9306 0.2181       NaN
# floors             0.0558 0.1608       NaN
# waterfront         0.1249 0.1786       NaN
# view               0.1012 0.2872       NaN
# condition          0.0324 0.0155       NaN
# grade              0.4124 0.5138       NaN
# sqft_above         0.4291 0.4012       NaN
# sqft_basement      0.0668 0.1927       NaN
# yr_built           0.2029 0.0562       NaN
# yr_renovated       0.0519 0.1147       NaN
# zipcode            0.4660 0.1093       NaN
# lat                0.1643 0.0535       NaN
# long               0.4877 0.0694       NaN
# sqft_living15      0.5547 0.3927       NaN
# sqft_lot15         1.0000 0.2171       NaN
# price              0.2171 1.0000       NaN
# price650              NaN    NaN       NaN

# %%
fig, ax = plt.subplots(figsize=(15,15))
mask = np.zeros_like(df.corr())
mask[np.triu_indices_from(mask)]=True
sns.heatmap(corr_650,
            cmap='seismic',
            mask=mask,
            center=0,
            annot=True,
            ax=ax)
# Out:
# <AxesSubplot:>

# %%
df.price.describe()
# Out:
# count      5322.0000
# mean     990965.0299
# std      478187.3874
# min      650000.0000
# 25%      725000.0000
# 50%      830000.0000
# 75%     1050000.0000
# max     7700000.0000
# Name: price, dtype: float64

# %%
df.price.hist()
# Out:
# <AxesSubplot:>

# %%
# df.price = np.log(df.price.values)

# %%
# df.price.hist()

# %% [markdown]
# ### Columns type

# %% [markdown]
# ### Drop not relevant columns

# %%
## df = df.drop(['id','lat', 'long', 'date', 'bedrooms', 'sqft_lot', 'floors', 'condition', 'sqft_above', 'sqft_basement', 'yr_renovated', 'sqft_living15', 'sqft_lot15'], axis=1)

# %% [markdown]
# ### Checking Columns

# %%
## df = df.drop(15856).reset_index(drop=True)

# %%
df
# Out:
#                id       date  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 5      7237550310 2014-05-12         4     4.5000         5420    101930
# 10     1736800520 2015-04-03         3     2.5000         3560      9796
# 15     9297300055 2015-01-24         4     3.0000         2950      5000
# 21     2524049179 2014-08-26         3     2.7500         3050     44867
# 26     1794500383 2014-06-26         3     1.7500         2450      2691
# ...           ...        ...       ...        ...          ...       ...
# 21580  7502800100 2014-08-13         5     2.7500         3600      9437
# 21581   191100405 2015-04-21         4     3.2500         3410     10125
# 21583  7202300110 2014-09-15         4     3.0000         3990      7838
# 21584   249000205 2014-10-15         5     3.7500         4470      8088
# 21590  7936000429 2015-03-26         4     3.5000         3510      7200
#
#        floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 5      1.0000           0     0          3     11        3890           1530
# 10     1.0000           0     0          3      8        1860           1700
# 15     2.0000           0     3          3      9        1980            970
# 21     1.0000           0     4          3      9        2330            720
# 26     2.0000           0     0          3      8        1750            700
# ...       ...         ...   ...        ...    ...         ...            ...
# 21580  2.0000           0     0          3      9        3600              0
# 21581  2.0000           0     0          3     10        3410              0
# 21583  2.0000           0     0          3      9        3990              0
# 21584  2.0000           0     0          3     11        4470              0
# 21590  2.0000           0     0          3      9        2600            910
#
#        yr_built  yr_renovated  zipcode     lat      long  sqft_living15  \
# 5          2001             0    98053 47.6561 -122.0050           4760
# 10         1965             0    98007 47.6007 -122.1450           2210
# 15         1979             0    98126 47.5714 -122.3750           2140
# 21         1968             0    98040 47.5316 -122.2330           4110
# 26         1915             0    98119 47.6386 -122.3600           1760
# ...         ...           ...      ...     ...       ...            ...
# 21580      2014             0    98059 47.4822 -122.1310           3550
# 21581      2007             0    98040 47.5653 -122.2230           2290
# 21583      2003             0    98053 47.6857 -122.0460           3370
# 21584      2008             0    98004 47.6321 -122.2000           2780
# 21590      2009             0    98136 47.5537 -122.3980           2050
#
#        sqft_lot15    price  price650
# 5          101930  1230000      True
# 10           8925   662500      True
# 15           4000   650000      True
# 21          20336  2000000      True
# 26           3573   937000      True
# ...           ...      ...       ...
# 21580        9421   679950      True
# 21581       10125  1580000      True
# 21583        6814   810000      True
# 21584        8964  1540000      True
# 21590        6200  1010000      True
#
# [5322 rows x 22 columns]

# %%
df['bathrooms'].value_counts()
# Out:
# 2.5000    1510
# 2.7500     534
# 3.5000     526
# 2.2500     465
# 1.7500     421
# 3.2500     397
# 3.0000     331
# 2.0000     300
# 1.0000     185
# 1.5000     167
# 3.7500     132
# 4.0000     117
# 4.5000      82
# 4.2500      74
# 4.7500      21
# 5.0000      17
# 5.2500      11
# 5.5000      10
# 6.0000       6
# 5.7500       3
# 6.7500       2
# 8.0000       2
# 0.7500       2
# 1.2500       2
# 6.2500       2
# 6.5000       2
# 7.7500       1
# Name: bathrooms, dtype: int64

# %%
df['bathrooms'] = round(df['bathrooms'])
df['bathrooms'] = np.where(df['bathrooms'] == 0, 1, df['bathrooms'])
df['bathrooms'] = np.where(df['bathrooms'] > 5, 5, df['bathrooms'])
df
# Out:
# /var/folders/nx/7crq4wx155z00jtfy6fbs9bw0000gn/T/ipykernel_23255/1667658948.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['bathrooms'] = round(df['bathrooms'])
# /var/folders/nx/7crq4wx155z00jtfy6fbs9bw0000gn/T/ipykernel_23255/1667658948.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['bathrooms'] = np.where(df['bathrooms'] == 0, 1, df['bathrooms'])
# /var/folders/nx/7crq4wx155z00jtfy6fbs9bw0000gn/T/ipykernel_23255/1667658948.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['bathrooms'] = np.where(df['bathrooms'] > 5, 5, df['bathrooms'])
#                id       date  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 5      7237550310 2014-05-12         4     4.0000         5420    101930
# 10     1736800520 2015-04-03         3     2.0000         3560      9796
# 15     9297300055 2015-01-24         4     3.0000         2950      5000
# 21     2524049179 2014-08-26         3     3.0000         3050     44867
# 26     1794500383 2014-06-26         3     2.0000         2450      2691
# ...           ...        ...       ...        ...          ...       ...
# 21580  7502800100 2014-08-13         5     3.0000         3600      9437
# 21581   191100405 2015-04-21         4     3.0000         3410     10125
# 21583  7202300110 2014-09-15         4     3.0000         3990      7838
# 21584   249000205 2014-10-15         5     4.0000         4470      8088
# 21590  7936000429 2015-03-26         4     4.0000         3510      7200
#
#        floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 5      1.0000           0     0          3     11        3890           1530
# 10     1.0000           0     0          3      8        1860           1700
# 15     2.0000           0     3          3      9        1980            970
# 21     1.0000           0     4          3      9        2330            720
# 26     2.0000           0     0          3      8        1750            700
# ...       ...         ...   ...        ...    ...         ...            ...
# 21580  2.0000           0     0          3      9        3600              0
# 21581  2.0000           0     0          3     10        3410              0
# 21583  2.0000           0     0          3      9        3990              0
# 21584  2.0000           0     0          3     11        4470              0
# 21590  2.0000           0     0          3      9        2600            910
#
#        yr_built  yr_renovated  zipcode     lat      long  sqft_living15  \
# 5          2001             0    98053 47.6561 -122.0050           4760
# 10         1965             0    98007 47.6007 -122.1450           2210
# 15         1979             0    98126 47.5714 -122.3750           2140
# 21         1968             0    98040 47.5316 -122.2330           4110
# 26         1915             0    98119 47.6386 -122.3600           1760
# ...         ...           ...      ...     ...       ...            ...
# 21580      2014             0    98059 47.4822 -122.1310           3550
# 21581      2007             0    98040 47.5653 -122.2230           2290
# 21583      2003             0    98053 47.6857 -122.0460           3370
# 21584      2008             0    98004 47.6321 -122.2000           2780
# 21590      2009             0    98136 47.5537 -122.3980           2050
#
#        sqft_lot15    price  price650
# 5          101930  1230000      True
# 10           8925   662500      True
# 15           4000   650000      True
# 21          20336  2000000      True
# 26           3573   937000      True
# ...           ...      ...       ...
# 21580        9421   679950      True
# 21581       10125  1580000      True
# 21583        6814   810000      True
# 21584        8964  1540000      True
# 21590        6200  1010000      True
#
# [5322 rows x 22 columns]

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Transform yr_built and yr_renovated

# %%
df['yr_built']= list(map(lambda x: 2015-x, df['yr_built']))
# Out:
# /var/folders/nx/7crq4wx155z00jtfy6fbs9bw0000gn/T/ipykernel_23255/3099508702.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['yr_built']= list(map(lambda x: 2015-x, df['yr_built']))

# %%
df['yr_built']
# Out:
# 5         14
# 10        50
# 15        36
# 21        47
# 26       100
#         ...
# 21580      1
# 21581      8
# 21583     12
# 21584      7
# 21590      6
# Name: yr_built, Length: 5322, dtype: int64

# %%
df.rename(columns = {'yr_built' : 'age_build'}, inplace=True)
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
df
# Out:
#            date  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0    2015-02-23         3     2.0000       0.1067      5657  1.5000
# 1    2014-11-21         4     2.0000       0.2221      7051  2.0000
# 2    2014-10-22         3     2.0000       0.1494      5467  2.0000
# 3    2014-10-08         2     2.0000       0.1123      3313  2.0000
# 4    2015-03-11         5     3.0000       0.1842      5934  2.0000
# ...         ...       ...        ...          ...       ...     ...
# 5317 2015-02-02         6     4.0000       0.3929     13928  2.0000
# 5318 2014-05-20         4     2.0000       0.1320     12100  1.0000
# 5319 2014-10-13         2     2.0000       0.0941      8112  1.0000
# 5320 2014-06-24         4     4.0000       0.1818     31450  2.0000
# 5321 2014-06-24         4     2.0000       0.2103     13900  1.0000
#
#       waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0              0     2          4      8        1910            330
# 1              0     0          3     11        3700              0
# 2              0     2          3      9        2780              0
# 3              0     0          3      9        2310              0
# 4              0     0          3      9        3220              0
# ...          ...   ...        ...    ...         ...            ...
# 5317           0     3          3     10        4150           1710
# 5318           0     0          4      8        1760            800
# 5319           1     4          4      8        1040           1040
# 5320           0     0          3      9        3190              0
# 5321           0     0          3      8        1830           1720
#
#       age_build  yr_renovated     lat      long  sqft_living15  sqft_lot15  \
# 0            74             0 47.6621 -122.2700           2970        5657
# 1             9             0 47.5427 -121.9950           3580        6175
# 2            15             0 47.5791 -122.3780           2630        5000
# 3             9             0 47.6318 -122.3650           2700        5670
# 4             9             0 47.7076 -122.1010           3100        5934
# ...         ...           ...     ...       ...            ...         ...
# 5317          2             0 47.5382 -122.1140           5790       13928
# 5318         39             0 47.6310 -122.1080           2240       12100
# 5319         76          1984 47.7134 -122.2770           2030        8408
# 5320          5             0 47.5010 -121.9020           3000       72745
# 5321          5             0 47.5681 -122.1270           2770       12200
#
#         price quantile_zip
# 0     1270000           10
# 1      950000            3
# 2      775000            2
# 3     1250000            8
# 4      798000            2
# ...       ...          ...
# 5317  1750000            9
# 5318   765000            2
# 5319  1190000            6
# 5320   790000            7
# 5321   859000            9
#
# [5322 rows x 20 columns]

# %%
df['renov_yn'] = np.where(df.yr_renovated != 0, 1, 0)

# %%
df
# Out:
#            date  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0    2015-02-23         3     2.0000       0.1067      5657  1.5000
# 1    2014-11-21         4     2.0000       0.2221      7051  2.0000
# 2    2014-10-22         3     2.0000       0.1494      5467  2.0000
# 3    2014-10-08         2     2.0000       0.1123      3313  2.0000
# 4    2015-03-11         5     3.0000       0.1842      5934  2.0000
# ...         ...       ...        ...          ...       ...     ...
# 5317 2015-02-02         6     4.0000       0.3929     13928  2.0000
# 5318 2014-05-20         4     2.0000       0.1320     12100  1.0000
# 5319 2014-10-13         2     2.0000       0.0941      8112  1.0000
# 5320 2014-06-24         4     4.0000       0.1818     31450  2.0000
# 5321 2014-06-24         4     2.0000       0.2103     13900  1.0000
#
#       waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0              0     2          4      8        1910            330
# 1              0     0          3     11        3700              0
# 2              0     2          3      9        2780              0
# 3              0     0          3      9        2310              0
# 4              0     0          3      9        3220              0
# ...          ...   ...        ...    ...         ...            ...
# 5317           0     3          3     10        4150           1710
# 5318           0     0          4      8        1760            800
# 5319           1     4          4      8        1040           1040
# 5320           0     0          3      9        3190              0
# 5321           0     0          3      8        1830           1720
#
#       age_build  yr_renovated     lat      long  sqft_living15  sqft_lot15  \
# 0            74             0 47.6621 -122.2700           2970        5657
# 1             9             0 47.5427 -121.9950           3580        6175
# 2            15             0 47.5791 -122.3780           2630        5000
# 3             9             0 47.6318 -122.3650           2700        5670
# 4             9             0 47.7076 -122.1010           3100        5934
# ...         ...           ...     ...       ...            ...         ...
# 5317          2             0 47.5382 -122.1140           5790       13928
# 5318         39             0 47.6310 -122.1080           2240       12100
# 5319         76          1984 47.7134 -122.2770           2030        8408
# 5320          5             0 47.5010 -121.9020           3000       72745
# 5321          5             0 47.5681 -122.1270           2770       12200
#
#         price quantile_zip  renov_yn
# 0     1270000           10         0
# 1      950000            3         0
# 2      775000            2         0
# 3     1250000            8         0
# 4      798000            2         0
# ...       ...          ...       ...
# 5317  1750000            9         0
# 5318   765000            2         0
# 5319  1190000            6         1
# 5320   790000            7         0
# 5321   859000            9         0
#
# [5322 rows x 21 columns]

# %% [markdown]
# ### Transform zipcode

# %%
price_zip_mean = df.groupby(['zipcode'])['price'].mean()
price_zip_mean.sort_values(ascending=False)
# Out:
# zipcode
# 98039   2161300.0000
# 98004   1396656.6611
# 98112   1256294.3952
# 98040   1233758.0679
# 98102   1127675.3538
#             ...
# 98031    746533.3333
# 98010    737830.5556
# 98022    736714.2857
# 98133    713942.3571
# 98188    706500.0000
# Name: price, Length: 63, dtype: float64

# %%
price_zip = df.groupby(['zipcode'])['price'].mean()
pz = price_zip.sort_values(ascending=False).reset_index()
pz
# Out:
#     zipcode        price
# 0     98039 2161300.0000
# 1     98004 1396656.6611
# 2     98112 1256294.3952
# 3     98040 1233758.0679
# 4     98102 1127675.3538
# ..      ...          ...
# 58    98031  746533.3333
# 59    98010  737830.5556
# 60    98022  736714.2857
# 61    98133  713942.3571
# 62    98188  706500.0000
#
# [63 rows x 2 columns]

# %%
df
# Out:
#                id       date  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 5      7237550310 2014-05-12         4     4.0000         5420    101930
# 10     1736800520 2015-04-03         3     2.0000         3560      9796
# 15     9297300055 2015-01-24         4     3.0000         2950      5000
# 21     2524049179 2014-08-26         3     3.0000         3050     44867
# 26     1794500383 2014-06-26         3     2.0000         2450      2691
# ...           ...        ...       ...        ...          ...       ...
# 21580  7502800100 2014-08-13         5     3.0000         3600      9437
# 21581   191100405 2015-04-21         4     3.0000         3410     10125
# 21583  7202300110 2014-09-15         4     3.0000         3990      7838
# 21584   249000205 2014-10-15         5     4.0000         4470      8088
# 21590  7936000429 2015-03-26         4     4.0000         3510      7200
#
#        floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 5      1.0000           0     0          3     11        3890           1530
# 10     1.0000           0     0          3      8        1860           1700
# 15     2.0000           0     3          3      9        1980            970
# 21     1.0000           0     4          3      9        2330            720
# 26     2.0000           0     0          3      8        1750            700
# ...       ...         ...   ...        ...    ...         ...            ...
# 21580  2.0000           0     0          3      9        3600              0
# 21581  2.0000           0     0          3     10        3410              0
# 21583  2.0000           0     0          3      9        3990              0
# 21584  2.0000           0     0          3     11        4470              0
# 21590  2.0000           0     0          3      9        2600            910
#
#        age_build  yr_renovated  zipcode     lat      long  sqft_living15  \
# 5             14             0    98053 47.6561 -122.0050           4760
# 10            50             0    98007 47.6007 -122.1450           2210
# 15            36             0    98126 47.5714 -122.3750           2140
# 21            47             0    98040 47.5316 -122.2330           4110
# 26           100             0    98119 47.6386 -122.3600           1760
# ...          ...           ...      ...     ...       ...            ...
# 21580          1             0    98059 47.4822 -122.1310           3550
# 21581          8             0    98040 47.5653 -122.2230           2290
# 21583         12             0    98053 47.6857 -122.0460           3370
# 21584          7             0    98004 47.6321 -122.2000           2780
# 21590          6             0    98136 47.5537 -122.3980           2050
#
#        sqft_lot15    price  price650
# 5          101930  1230000      True
# 10           8925   662500      True
# 15           4000   650000      True
# 21          20336  2000000      True
# 26           3573   937000      True
# ...           ...      ...       ...
# 21580        9421   679950      True
# 21581       10125  1580000      True
# 21583        6814   810000      True
# 21584        8964  1540000      True
# 21590        6200  1010000      True
#
# [5322 rows x 22 columns]

# %%
Q1 = np.percentile(pz['price'], 10)
Q2 = np.percentile(pz['price'], 20)
Q3 = np.percentile(pz['price'], 30)
Q4 = np.percentile(pz['price'], 40)
Q5 = np.percentile(pz['price'], 50)
Q6 = np.percentile(pz['price'], 60)
Q7 = np.percentile(pz['price'], 70)
Q8 = np.percentile(pz['price'], 80)
Q9 = np.percentile(pz['price'], 90)

# %%
pz['quantile_zip'] = "1"
pz['quantile_zip'] = np.where(pz['price'] >= Q1, "2", pz['quantile_zip'])
pz['quantile_zip'] = np.where(pz['price'] >= Q2, "3", pz['quantile_zip'])
pz['quantile_zip'] = np.where(pz['price'] >= Q3, "4", pz['quantile_zip'])
pz['quantile_zip'] = np.where(pz['price'] >= Q4, "5", pz['quantile_zip'])
pz['quantile_zip'] = np.where(pz['price'] >= Q5, "6", pz['quantile_zip'])
pz['quantile_zip'] = np.where(pz['price'] >= Q6, "7", pz['quantile_zip'])
pz['quantile_zip'] = np.where(pz['price'] >= Q7, "8", pz['quantile_zip'])
pz['quantile_zip'] = np.where(pz['price'] >= Q8, "9", pz['quantile_zip'])
pz['quantile_zip'] = np.where(pz['price'] >= Q9, "10", pz['quantile_zip'])

# %%
pz
# Out:
#     zipcode        price quantile_zip
# 0     98039 2161300.0000           10
# 1     98004 1396656.6611           10
# 2     98112 1256294.3952           10
# 3     98040 1233758.0679           10
# 4     98102 1127675.3538           10
# ..      ...          ...          ...
# 58    98031  746533.3333            1
# 59    98010  737830.5556            1
# 60    98022  736714.2857            1
# 61    98133  713942.3571            1
# 62    98188  706500.0000            1
#
# [63 rows x 3 columns]

# %%
pz.groupby('quantile_zip').count()
# Out:
#               zipcode  price
# quantile_zip
# 1                   7      7
# 10                  7      7
# 2                   6      6
# 3                   6      6
# 4                   6      6
# 5                   6      6
# 6                   7      7
# 7                   6      6
# 8                   6      6
# 9                   6      6

# %%
df = pd.merge(df, pz[['zipcode', 'quantile_zip']], on='zipcode', how='inner').sample(frac=1).reset_index(drop=True)

# %%
df
# Out:
#               id       date  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0     4218400175 2015-02-23         3     2.0000         2240      5657
# 1     3629921000 2014-11-21         4     2.0000         3700      7051
# 2     9577800005 2014-10-22         3     2.0000         2780      5467
# 3     1732801300 2014-10-08         2     2.0000         2310      3313
# 4     2568200170 2015-03-11         5     3.0000         3220      5934
# ...          ...        ...       ...        ...          ...       ...
# 5317   715010130 2015-02-02         6     4.0000         5860     13928
# 5318  2525059077 2014-05-20         4     2.0000         2560     12100
# 5319  7352200025 2014-10-13         2     2.0000         2080      8112
# 5320   323079065 2014-06-24         4     4.0000         3190     31450
# 5321  1777600850 2014-06-24         4     2.0000         3550     13900
#
#       floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0     1.5000           0     2          4      8        1910            330
# 1     2.0000           0     0          3     11        3700              0
# 2     2.0000           0     2          3      9        2780              0
# 3     2.0000           0     0          3      9        2310              0
# 4     2.0000           0     0          3      9        3220              0
# ...      ...         ...   ...        ...    ...         ...            ...
# 5317  2.0000           0     3          3     10        4150           1710
# 5318  1.0000           0     0          4      8        1760            800
# 5319  1.0000           1     4          4      8        1040           1040
# 5320  2.0000           0     0          3      9        3190              0
# 5321  1.0000           0     0          3      8        1830           1720
#
#       age_build  yr_renovated  zipcode     lat      long  sqft_living15  \
# 0            74             0    98105 47.6621 -122.2700           2970
# 1             9             0    98029 47.5427 -121.9950           3580
# 2            15             0    98126 47.5791 -122.3780           2630
# 3             9             0    98119 47.6318 -122.3650           2700
# 4             9             0    98052 47.7076 -122.1010           3100
# ...         ...           ...      ...     ...       ...            ...
# 5317          2             0    98006 47.5382 -122.1140           5790
# 5318         39             0    98052 47.6310 -122.1080           2240
# 5319         76          1984    98125 47.7134 -122.2770           2030
# 5320          5             0    98027 47.5010 -121.9020           3000
# 5321          5             0    98006 47.5681 -122.1270           2770
#
#       sqft_lot15    price  price650 quantile_zip
# 0           5657  1270000      True           10
# 1           6175   950000      True            3
# 2           5000   775000      True            2
# 3           5670  1250000      True            8
# 4           5934   798000      True            2
# ...          ...      ...       ...          ...
# 5317       13928  1750000      True            9
# 5318       12100   765000      True            2
# 5319        8408  1190000      True            6
# 5320       72745   790000      True            7
# 5321       12200   859000      True            9
#
# [5322 rows x 23 columns]

# %%
scaler = MinMaxScaler()
df['sqft_living'] = scaler.fit_transform(df[['sqft_living']])

# %%
df
# Out:
#               id       date  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0     4218400175 2015-02-23         3     2.0000       0.1067      5657
# 1     3629921000 2014-11-21         4     2.0000       0.2221      7051
# 2     9577800005 2014-10-22         3     2.0000       0.1494      5467
# 3     1732801300 2014-10-08         2     2.0000       0.1123      3313
# 4     2568200170 2015-03-11         5     3.0000       0.1842      5934
# ...          ...        ...       ...        ...          ...       ...
# 5317   715010130 2015-02-02         6     4.0000       0.3929     13928
# 5318  2525059077 2014-05-20         4     2.0000       0.1320     12100
# 5319  7352200025 2014-10-13         2     2.0000       0.0941      8112
# 5320   323079065 2014-06-24         4     4.0000       0.1818     31450
# 5321  1777600850 2014-06-24         4     2.0000       0.2103     13900
#
#       floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0     1.5000           0     2          4      8        1910            330
# 1     2.0000           0     0          3     11        3700              0
# 2     2.0000           0     2          3      9        2780              0
# 3     2.0000           0     0          3      9        2310              0
# 4     2.0000           0     0          3      9        3220              0
# ...      ...         ...   ...        ...    ...         ...            ...
# 5317  2.0000           0     3          3     10        4150           1710
# 5318  1.0000           0     0          4      8        1760            800
# 5319  1.0000           1     4          4      8        1040           1040
# 5320  2.0000           0     0          3      9        3190              0
# 5321  1.0000           0     0          3      8        1830           1720
#
#       age_build  yr_renovated  zipcode     lat      long  sqft_living15  \
# 0            74             0    98105 47.6621 -122.2700           2970
# 1             9             0    98029 47.5427 -121.9950           3580
# 2            15             0    98126 47.5791 -122.3780           2630
# 3             9             0    98119 47.6318 -122.3650           2700
# 4             9             0    98052 47.7076 -122.1010           3100
# ...         ...           ...      ...     ...       ...            ...
# 5317          2             0    98006 47.5382 -122.1140           5790
# 5318         39             0    98052 47.6310 -122.1080           2240
# 5319         76          1984    98125 47.7134 -122.2770           2030
# 5320          5             0    98027 47.5010 -121.9020           3000
# 5321          5             0    98006 47.5681 -122.1270           2770
#
#       sqft_lot15    price  price650 quantile_zip
# 0           5657  1270000      True           10
# 1           6175   950000      True            3
# 2           5000   775000      True            2
# 3           5670  1250000      True            8
# 4           5934   798000      True            2
# ...          ...      ...       ...          ...
# 5317       13928  1750000      True            9
# 5318       12100   765000      True            2
# 5319        8408  1190000      True            6
# 5320       72745   790000      True            7
# 5321       12200   859000      True            9
#
# [5322 rows x 23 columns]

# %%
df = df.drop(['id','price650', 'zipcode'], axis=1)

# %%
df
# Out:
#            date  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0    2015-02-23         3     2.0000       0.1067      5657  1.5000
# 1    2014-11-21         4     2.0000       0.2221      7051  2.0000
# 2    2014-10-22         3     2.0000       0.1494      5467  2.0000
# 3    2014-10-08         2     2.0000       0.1123      3313  2.0000
# 4    2015-03-11         5     3.0000       0.1842      5934  2.0000
# ...         ...       ...        ...          ...       ...     ...
# 5317 2015-02-02         6     4.0000       0.3929     13928  2.0000
# 5318 2014-05-20         4     2.0000       0.1320     12100  1.0000
# 5319 2014-10-13         2     2.0000       0.0941      8112  1.0000
# 5320 2014-06-24         4     4.0000       0.1818     31450  2.0000
# 5321 2014-06-24         4     2.0000       0.2103     13900  1.0000
#
#       waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0              0     2          4      8        1910            330
# 1              0     0          3     11        3700              0
# 2              0     2          3      9        2780              0
# 3              0     0          3      9        2310              0
# 4              0     0          3      9        3220              0
# ...          ...   ...        ...    ...         ...            ...
# 5317           0     3          3     10        4150           1710
# 5318           0     0          4      8        1760            800
# 5319           1     4          4      8        1040           1040
# 5320           0     0          3      9        3190              0
# 5321           0     0          3      8        1830           1720
#
#       age_build  yr_renovated     lat      long  sqft_living15  sqft_lot15  \
# 0            74             0 47.6621 -122.2700           2970        5657
# 1             9             0 47.5427 -121.9950           3580        6175
# 2            15             0 47.5791 -122.3780           2630        5000
# 3             9             0 47.6318 -122.3650           2700        5670
# 4             9             0 47.7076 -122.1010           3100        5934
# ...         ...           ...     ...       ...            ...         ...
# 5317          2             0 47.5382 -122.1140           5790       13928
# 5318         39             0 47.6310 -122.1080           2240       12100
# 5319         76          1984 47.7134 -122.2770           2030        8408
# 5320          5             0 47.5010 -121.9020           3000       72745
# 5321          5             0 47.5681 -122.1270           2770       12200
#
#         price quantile_zip
# 0     1270000           10
# 1      950000            3
# 2      775000            2
# 3     1250000            8
# 4      798000            2
# ...       ...          ...
# 5317  1750000            9
# 5318   765000            2
# 5319  1190000            6
# 5320   790000            7
# 5321   859000            9
#
# [5322 rows x 20 columns]

# %%
## rechecking corr after cleaning

# %%
corr_650_clean = df.corr(method='spearman').abs()
corr_650_clean
# Out:
#                bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# bedrooms         1.0000     0.4128       0.4753    0.1427  0.1761      0.0574
# bathrooms        0.4128     1.0000       0.6175    0.1453  0.2901      0.0376
# sqft_living      0.4753     0.6175       1.0000    0.4468  0.3623      0.0486
# sqft_lot         0.1427     0.1453       0.4468    1.0000  0.0748      0.1153
# floors           0.1761     0.2901       0.3623    0.0748  1.0000      0.0037
# waterfront       0.0574     0.0376       0.0486    0.1153  0.0037      1.0000
# view             0.0265     0.1153       0.1360    0.1009  0.0923      0.3400
# condition        0.0406     0.1676       0.2231    0.0297  0.3286      0.0070
# grade            0.2196     0.4491       0.6959    0.3956  0.4369      0.0369
# sqft_above       0.3695     0.4790       0.8173    0.4339  0.6007      0.0131
# sqft_basement    0.1542     0.2189       0.1958    0.0560  0.3627      0.0713
# age_build        0.1328     0.3307       0.4284    0.1679  0.4453      0.0415
# yr_renovated     0.0202     0.0665       0.0240    0.0497  0.0087      0.0932
# lat              0.0640     0.1060       0.1392    0.1613  0.0350      0.0923
# long             0.1515     0.1353       0.3639    0.4779  0.1962      0.0524
# sqft_living15    0.2452     0.2956       0.6177    0.5115  0.1983      0.0551
# sqft_lot15       0.1313     0.1391       0.4342    0.9306  0.0558      0.1249
# price            0.2267     0.3939       0.5331    0.2181  0.1608      0.1786
#
#                 view  condition  grade  sqft_above  sqft_basement  age_build  \
# bedrooms      0.0265     0.0406 0.2196      0.3695         0.1542     0.1328
# bathrooms     0.1153     0.1676 0.4491      0.4790         0.2189     0.3307
# sqft_living   0.1360     0.2231 0.6959      0.8173         0.1958     0.4284
# sqft_lot      0.1009     0.0297 0.3956      0.4339         0.0560     0.1679
# floors        0.0923     0.3286 0.4369      0.6007         0.3627     0.4453
# waterfront    0.3400     0.0070 0.0369      0.0131         0.0713     0.0415
# view          1.0000     0.0613 0.1053      0.0376         0.3138     0.1208
# condition     0.0613     1.0000 0.3130      0.3522         0.2360     0.5187
# grade         0.1053     0.3130 1.0000      0.7207         0.0829     0.5122
# sqft_above    0.0376     0.3522 0.7207      1.0000         0.3527     0.5615
# sqft_basement 0.3138     0.2360 0.0829      0.3527         1.0000     0.2691
# age_build     0.1208     0.5187 0.5122      0.5615         0.2691     1.0000
# yr_renovated  0.1108     0.1163 0.0711      0.0762         0.1055     0.2887
# lat           0.1445     0.0028 0.1621      0.1104         0.0338     0.0918
# long          0.2109     0.2587 0.3636      0.5092         0.3154     0.5275
# sqft_living15 0.1623     0.1630 0.6139      0.5975         0.0330     0.3375
# sqft_lot15    0.1012     0.0324 0.4124      0.4291         0.0668     0.2029
# price         0.2872     0.0155 0.5138      0.4012         0.1927     0.0562
#
#                yr_renovated    lat   long  sqft_living15  sqft_lot15  price
# bedrooms             0.0202 0.0640 0.1515         0.2452      0.1313 0.2267
# bathrooms            0.0665 0.1060 0.1353         0.2956      0.1391 0.3939
# sqft_living          0.0240 0.1392 0.3639         0.6177      0.4342 0.5331
# sqft_lot             0.0497 0.1613 0.4779         0.5115      0.9306 0.2181
# floors               0.0087 0.0350 0.1962         0.1983      0.0558 0.1608
# waterfront           0.0932 0.0923 0.0524         0.0551      0.1249 0.1786
# view                 0.1108 0.1445 0.2109         0.1623      0.1012 0.2872
# condition            0.1163 0.0028 0.2587         0.1630      0.0324 0.0155
# grade                0.0711 0.1621 0.3636         0.6139      0.4124 0.5138
# sqft_above           0.0762 0.1104 0.5092         0.5975      0.4291 0.4012
# sqft_basement        0.1055 0.0338 0.3154         0.0330      0.0668 0.1927
# age_build            0.2887 0.0918 0.5275         0.3375      0.2029 0.0562
# yr_renovated         1.0000 0.0096 0.1852         0.1040      0.0519 0.1147
# lat                  0.0096 1.0000 0.1985         0.1877      0.1643 0.0535
# long                 0.1852 0.1985 1.0000         0.5241      0.4877 0.0694
# sqft_living15        0.1040 0.1877 0.5241         1.0000      0.5547 0.3927
# sqft_lot15           0.0519 0.1643 0.4877         0.5547      1.0000 0.2171
# price                0.1147 0.0535 0.0694         0.3927      0.2171 1.0000

# %%
fig, ax = plt.subplots(figsize=(15,15))
mask = np.zeros_like(df.corr())
mask[np.triu_indices_from(mask)]=True
sns.heatmap(corr_650_clean,
            cmap='seismic',
            mask=mask,
            center=0,
            annot=True,
            ax=ax)
# Out:
# <AxesSubplot:>

# %%
df
# Out:
#            date  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0    2015-02-23         3     2.0000       0.1067      5657  1.5000
# 1    2014-11-21         4     2.0000       0.2221      7051  2.0000
# 2    2014-10-22         3     2.0000       0.1494      5467  2.0000
# 3    2014-10-08         2     2.0000       0.1123      3313  2.0000
# 4    2015-03-11         5     3.0000       0.1842      5934  2.0000
# ...         ...       ...        ...          ...       ...     ...
# 5317 2015-02-02         6     4.0000       0.3929     13928  2.0000
# 5318 2014-05-20         4     2.0000       0.1320     12100  1.0000
# 5319 2014-10-13         2     2.0000       0.0941      8112  1.0000
# 5320 2014-06-24         4     4.0000       0.1818     31450  2.0000
# 5321 2014-06-24         4     2.0000       0.2103     13900  1.0000
#
#       waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0              0     2          4      8        1910            330
# 1              0     0          3     11        3700              0
# 2              0     2          3      9        2780              0
# 3              0     0          3      9        2310              0
# 4              0     0          3      9        3220              0
# ...          ...   ...        ...    ...         ...            ...
# 5317           0     3          3     10        4150           1710
# 5318           0     0          4      8        1760            800
# 5319           1     4          4      8        1040           1040
# 5320           0     0          3      9        3190              0
# 5321           0     0          3      8        1830           1720
#
#       age_build  yr_renovated     lat      long  sqft_living15  sqft_lot15  \
# 0            74             0 47.6621 -122.2700           2970        5657
# 1             9             0 47.5427 -121.9950           3580        6175
# 2            15             0 47.5791 -122.3780           2630        5000
# 3             9             0 47.6318 -122.3650           2700        5670
# 4             9             0 47.7076 -122.1010           3100        5934
# ...         ...           ...     ...       ...            ...         ...
# 5317          2             0 47.5382 -122.1140           5790       13928
# 5318         39             0 47.6310 -122.1080           2240       12100
# 5319         76          1984 47.7134 -122.2770           2030        8408
# 5320          5             0 47.5010 -121.9020           3000       72745
# 5321          5             0 47.5681 -122.1270           2770       12200
#
#         price quantile_zip
# 0     1270000           10
# 1      950000            3
# 2      775000            2
# 3     1250000            8
# 4      798000            2
# ...       ...          ...
# 5317  1750000            9
# 5318   765000            2
# 5319  1190000            6
# 5320   790000            7
# 5321   859000            9
#
# [5322 rows x 20 columns]

# %% [markdown]
# conclusions: after filtering only the expensive houses, features - incl. those found to be informative for the original df, emerge as uninformative. Hence, linear regression would probably be worse.

# %%
df.to_excel("over650.xlsx")

# %% [markdown]
# ## Linear Regression (trial 5) - did not run!

# %% [markdown]
# #### XY Split

# %%
X5=df.drop('price', axis=1)
X5
y5=df.price
y5
# Out:
# 0       1310000
# 1        754999
# 2        710000
# 3       1950000
# 4        750000
#          ...
# 5317    1860000
# 5318     682000
# 5319     760000
# 5320     698000
# 5321     710000
# Name: price, Length: 5322, dtype: int64

# %%
X5
# Out:
#               id       date  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0     9273200140 2015-01-21         2     2.0000       0.2419      3938
# 1     6705850300 2015-04-14         4     2.0000       0.1676      9323
# 2     8691300500 2014-10-28         4     2.0000       0.1573     12349
# 3     3760500280 2014-10-14         3     2.0000       0.1281     12779
# 4     8928100025 2015-03-24         4     2.0000       0.0838      6300
# ...          ...        ...       ...        ...          ...       ...
# 5317  9471200065 2014-10-15         5     3.0000       0.3700      9600
# 5318  7300200400 2014-11-05         4     2.0000       0.1233     34092
# 5319  6752510010 2014-08-05         4     2.0000       0.1605      7901
# 5320  1725059209 2014-09-29         6     2.0000       0.1415     11250
# 5321  3885805935 2014-09-26         4     2.0000       0.0672      9000
#
#       floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0     2.0000           0     4          3     10        2910           1040
# 1     2.0000           0     0          3     10        3010              0
# 2     2.0000           0     0          3     10        2880              0
# 3     1.5000           0     4          3     10        2510              0
# 4     1.5000           0     1          3      7        1650            300
# ...      ...         ...   ...        ...    ...         ...            ...
# 5317  2.0000           0     0          5      9        3860           1710
# 5318  2.0000           0     0          4      8        2450              0
# 5319  2.0000           0     0          3      9        2920              0
# 5320  1.0000           0     0          5      7        1340           1340
# 5321  1.0000           0     0          5      8        1740              0
#
#       age_build  yr_renovated     lat      long  sqft_living15  sqft_lot15  \
# 0            24             0 47.5912 -122.3840           3220        4500
# 1            23             0 47.5780 -122.0530           2840        8413
# 2            19             0 47.5879 -121.9730           3490       11539
# 3            47             0 47.6982 -122.2310           2810       12225
# 4            71             0 47.6819 -122.2710           1760        6300
# ...         ...           ...     ...       ...            ...         ...
# 5317         63             0 47.6708 -122.2620           3170       10400
# 5318         35             0 47.5751 -122.0490           2410       35378
# 5319         11             0 47.7036 -122.1250           3020        7900
# 5320         48             0 47.6553 -122.1900           2200        9875
# 5321         57             0 47.6815 -122.1980           1850        7700
#
#       price650 quantile_zip
# 0         True            6
# 1         True            5
# 2         True            5
# 3         True            9
# 4         True            5
# ...        ...          ...
# 5317      True           10
# 5318      True            5
# 5319      True            2
# 5320      True            8
# 5321      True            8
#
# [5322 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['id', 'date', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'age_build', 'yr_renovated', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15', 'price', 'price650', 'quantile_zip'],
#       dtype='object')

# %% [markdown]
# #### Data Splitting

# %%
X_train5, X_test5, y_train5, y_test5 = train_test_split(X5, y5, test_size=.30,random_state=123)

# %% [markdown]
# #### Standardize

# %%
std_scaler5 = StandardScaler().fit(X_train5) 

X_train_scaled5 = std_scaler5.transform(X_train5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/nx/7crq4wx155z00jtfy6fbs9bw0000gn/T/ipykernel_23115/914248687.py in <module>
# ----> 1 std_scaler5 = StandardScaler().fit(X_train5)
#       2
#       3 X_train_scaled5 = std_scaler5.transform(X_train5)
#
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_data.py in fit(self, X, y, sample_weight)
#     728         # Reset internal state before fitting
#     729         self._reset()
# --> 730         return self.partial_fit(X, y, sample_weight)
#     731
#     732     def partial_fit(self, X, y=None, sample_weight=None):
#
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_data.py in partial_fit(self, X, y, sample_weight)
#     764         """
#     765         first_call = not hasattr(self, "n_samples_seen_")
# --> 766         X = self._validate_data(X, accept_sparse=('csr', 'csc'),
#     767                                 estimator=self, dtype=FLOAT_DTYPES,
#     768                                 force_all_finite='allow-nan', reset=first_call)
#
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     419             out = X
#     420         elif isinstance(y, str) and y == 'no_validation':
# --> 421             X = check_array(X, **check_params)
#     422             out = X
#     423         else:
#
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     595
#     596         if all(isinstance(dtype, np.dtype) for dtype in dtypes_orig):
# --> 597             dtype_orig = np.result_type(*dtypes_orig)
#     598
#     599     if dtype_numeric:
#
# <__array_function__ internals> in result_type(*args, **kwargs)
#
# TypeError: The DTypes <class 'numpy.dtype[datetime64]'> and <class 'numpy.dtype[int64]'> do not have a common DType. For example they cannot be stored in a single array unless the dtype is `object`.

# %%
X_test_scaled5 = std_scaler5.transform(X_test5)

# %%
print(X_train_scaled5)
print("--------")
print(X_test_scaled5)

# %%
X_train_const_scaled5 = sm.add_constant(X_train_scaled5) 

model5 = sm.OLS(y_train5, X_train_const_scaled5).fit()
predictions_train5 = model5.predict(X_train_const_scaled5) 

X_test_const_scaled5 = sm.add_constant(X_test_scaled5) 
predictions_test5 = model5.predict(X_test_const_scaled5) 
print_model5 = model5.summary()
print(print_model5)

# %% [markdown]
# #### Model validation

# %%
#using sklearn
model5=LinearRegression()    # model
model5.fit(X_train_scaled5, y_train5)   # model train

# %%
model5.coef_ #gives you per column the slope (alpha)

# %%
model5.intercept_ #gives the optimal slope

# %%
R2_test5 = model5.score(X_test_scaled5,y_test5) # measure R2
R2_test5

# %%
# Making prediction
y_pred5 = model5.predict(X_test_scaled5)
y_pred5

# %%
y_test5

# %%
result=pd.DataFrame({"y_test":y_test5,"y_pred":y_pred5})

# %%
# Make an scatter plot y_pred vs y
# What kind of plot you will get if all the all the predictions are ok?
# A stright line

fig, ax = plt.subplots(1,3,figsize=(14,4))
ax[0].plot(y_pred5, y_test5, 'o')
ax[0].set_xlabel("y_test")
ax[0].set_ylabel("y_pred")
ax[0].set_title("Test Set -Predicted vs real")

# Get a histogram of the residuals ie: y - y_pred.  Homoscdasticity
# It resembles a normal distribution?
ax[1].hist(y_test5 - y_pred5)
ax[1].set_xlabel("Test y-y_pred")
ax[1].set_title("Test Set Residual histogram")

ax[2].plot(y_pred5,y_test5 - y_pred5,"o")
ax[2].set_xlabel("predited")
ax[2].set_ylabel("residuals")
ax[2].set_title("Residuals by Predicted")
ax[2].plot(y_pred5,np.zeros(len(y_pred5)),linestyle='dashed')

# %%
sns.regplot(x='y_pred',y='y_test', data=result, scatter_kws={"color": "red"}, line_kws={"color": "black"})

# %% [markdown]
# #### Error metrics

# %%
print(mse(y_test5,y_pred5))
print(mae(y_test5,y_pred5))

# %% [markdown]
# #### Features Importance

# %%
features_importances5 = pd.DataFrame(data={
    'Attribute': X_train5.columns,
    'Importance': abs(model5.coef_)
})
features_importances5 = features_importances5.sort_values(by='Importance', ascending=False)
features_importances5
